# %% [markdown]
# # Is the IC result robust across alternate histories, not just across dates?
#
# `scorer_comparison.ipynb` found every scorer's mean IC statistically
# indistinguishable from zero using `evaluation.ic_significance` -- but
# that test only uses date-to-date variation WITHIN the one real price
# history we have (~40-50 rebalance dates). This notebook uses the
# existing `src/statioinary_bootstrap.py` engine to generate many
# synthetic-but-realistic alternate histories (same dates/tickers,
# block-resampled returns/volume) and asks the same question with many
# more independent samples: across worlds, not just across dates.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from scipy import stats

from src import data_broker, calendar_iterator, statioinary_bootstrap, metrics, analysis
from src2 import vectorized_scorers, evaluation, bootstrap_compare, alpha_engine, run_vectorized

# %% [markdown]
# ## 1. Data (same universe as scorer_comparison.ipynb)

# %%
tickers = 'ALGN,AAPL,PANW,AMD,ZS,MDLZ,XEL,VRSN,INSM,ON,WDAY,ENPH,DLTR,ADI,COST,ABNB,CEG,MSFT,GOOGL,CDNS,PYPL,FAST,JD,MTCH,SNPS,LULU,CMCSA,ADBE,ADSK'.split(',')

tickers=tickers+['SPY','QQQ']

broker = data_broker.DataBroker(tickers=tickers, start_date="2022-01-01", end_date="2026-04-01")
universe_data = broker.fetch_universe_data()

calendar = calendar_iterator.CalendarIterator(universe_data, interval="ME")
rebalance_dates = calendar.generate_rebalance_dates()
# Out:
# [*********************100%***********************]  31 of 31 completed

# %%
# benchmark_ticker=['SPY','QQQ']
# bench_broker = data_broker.DataBroker(tickers=['SPY', 'QQQ'], start_date="2022-01-01", end_date="2026-04-01")
# bench_price = bench_broker.fetch_universe_data()['price']

# %% [markdown]
# ## 2. Generate synthetic worlds via stationary bootstrap

# %%
NUM_SIMULATIONS = 1000

engine = statioinary_bootstrap.VectorizedBootstrapEngine(universe_data, expected_block_size=21)
bootstrap_result = engine.generate_all_worlds(num_simulations=NUM_SIMULATIONS)

bootstrap_result['price_tensor'].shape
# Out:
# (1000, 1063, 31)

# %% [markdown]
# Note: the bootstrap engine trims one day computing `pct_change()`, so
# `dates_index`/`tickers` must come from the engine itself, not the raw
# `universe_data`, to stay aligned with the tensor shapes.

# %%
dates_index = engine.dates_index
eng_tickers = engine.tickers
eng_rebalance_dates = [d for d in rebalance_dates if d in set(dates_index)]
len(dates_index), len(eng_rebalance_dates)
# Out:
# (1063, 51)

# %% [markdown]
# ## 3. Bootstrap IC distribution per scorer

# %%
SCORER_CONFIGS = {
    # "mean_reversion_40d": dict(score_fn=vectorized_scorers.rolling_mean_reversion_score, window=40),
    # "mean_reversion_60d": dict(score_fn=vectorized_scorers.rolling_mean_reversion_score, window=60),
    "geometric_drift_126d": dict(score_fn=vectorized_scorers.rolling_geometric_drift_score, window=126),
    "geometric_drift_252d": dict(score_fn=vectorized_scorers.rolling_geometric_drift_score, window=252),
}

# %% [markdown]
# ## 4. Run every scorer on every bootstrap world, collect `metrics.calculate_metrics`
#
# For each of the `NUM_SIMULATIONS` synthetic worlds: build the synthetic
# `{'price', 'volume'}` universe, run every scorer config through the same
# `alpha_engine` -> `run_vectorized` pipeline as `scorer_comparison.ipynb`,
# assemble a `df_nav_all` (benchmark + each scorer's NAV), and run
# `metrics.calculate_metrics(df_nav_all)` on it -- exactly like section 4 of
# `scorer_comparison.ipynb`, just repeated across worlds. The benchmark
# (SPY/QQQ) is real data, reindexed onto the synthetic dates_index -- it's
# the same every simulation, giving a fixed reference point per world.

# %%
from importlib import reload

# %%
reload(bootstrap_compare)
# Out:
# <module 'src2.bootstrap_compare' from '/Users/zhigangyu/Documents/codes/stock_simulation_system/src2/../src2/bootstrap_compare.py'>

# %%
import os
from concurrent.futures import ProcessPoolExecutor, as_completed

bench_tickers = ['SPY', 'QQQ']
WARMUP_DAYS = 252  # longest scorer lookback (geometric_drift_252d) -- drop this much NAV before scoring

price_tensor = bootstrap_result['price_tensor']
volume_tensor = bootstrap_result['volume_tensor']

bootstrap_metrics_rows = []
n_workers = os.cpu_count()
with ProcessPoolExecutor(max_workers=n_workers) as pool:
    futures = {
        pool.submit(
            bootstrap_compare.run_one_simulation,
            sim_id,
            price_tensor[sim_id],
            volume_tensor[sim_id],
            dates_index,
            eng_tickers,
            eng_rebalance_dates,
            SCORER_CONFIGS,
            bench_tickers,
            0.25,
            "equal",
            WARMUP_DAYS,
        ): sim_id
        for sim_id in range(NUM_SIMULATIONS)
    }

    done = 0
    for future in as_completed(futures):
        bootstrap_metrics_rows.append(future.result())
        done += 1
        if done % 20 == 0:
            print(f"{done}/{NUM_SIMULATIONS} simulations done")
# Out:
# 20/1000 simulations done
# 40/1000 simulations done
# 60/1000 simulations done
# 80/1000 simulations done
# 100/1000 simulations done
# 120/1000 simulations done
# 140/1000 simulations done
# 160/1000 simulations done
# 180/1000 simulations done
# 200/1000 simulations done
# 220/1000 simulations done
# 240/1000 simulations done
# 260/1000 simulations done
# 280/1000 simulations done
# 300/1000 simulations done
# 320/1000 simulations done
# 340/1000 simulations done
# 360/1000 simulations done
# 380/1000 simulations done
# 400/1000 simulations done
# 420/1000 simulations done
# 440/1000 simulations done
# 460/1000 simulations done
# 480/1000 simulations done
# 500/1000 simulations done
# 520/1000 simulations done
# 540/1000 simulations done
# 560/1000 simulations done
# 580/1000 simulations done
# 600/1000 simulations done
# 620/1000 simulations done
# 640/1000 simulations done
# 660/1000 simulations done
# 680/1000 simulations done
# 700/1000 simulations done
# 720/1000 simulations done
# 740/1000 simulations done
# 760/1000 simulations done
# 780/1000 simulations done
# 800/1000 simulations done
# 820/1000 simulations done
# 840/1000 simulations done
# 860/1000 simulations done
# 880/1000 simulations done
# 900/1000 simulations done
# 920/1000 simulations done
# 940/1000 simulations done
# 960/1000 simulations done
# 980/1000 simulations done
# 1000/1000 simulations done

# %%
bootstrap_metrics = pd.concat(bootstrap_metrics_rows, ignore_index=True)
bootstrap_metrics.shape
# Out:
# (4000, 7)

# %% [markdown]
# ### 4b. Peek at one synthetic world's rebased performance
#
# We don't collect `df_nav` for all `NUM_SIMULATIONS` worlds (returning a
# full NAV series per scorer per world from every `ProcessPoolExecutor`
# call would multiply the amount of data pickled back to the main process
# by ~`len(dates_index)`, for no benefit to the aggregate stats above) --
# but `bootstrap_compare.build_world_nav` is the same NAV-building code
# `run_one_simulation` uses internally, exposed standalone. Call it for a
# single `sim_id`, single-process, to get a `df_nav_all` in the exact shape
# `analysis.plot_rebased_performance` from `scorer_comparison.ipynb` expects.

# %%
from src import analysis

# %%
peek_sim_id = 0

df_nav_peek = bootstrap_compare.build_world_nav(
    peek_sim_id,
    price_tensor[peek_sim_id],
    volume_tensor[peek_sim_id],
    dates_index,
    eng_tickers,
    eng_rebalance_dates,
    SCORER_CONFIGS,
    bench_tickers,
)

analysis.plot_rebased_performance(df_nav_peek)

# %%
bootstrap_metrics.head()
# Out:
#    sim_id                scorer      CAGR  Sharpe_Ratio  Sortino_Ratio  \
# 0       3                   SPY  0.232177      1.563939       2.528210
# 1       3                   QQQ  0.313407      1.617720       2.682598
# 2       3  geometric_drift_126d  0.184947      0.966220       1.601388
# 3       3  geometric_drift_252d  0.275843      1.338982       2.282205
# 4       7                   SPY  0.234604      1.524357       2.662488
#
#    Max_Drawdown  Calmar_Ratio
# 0      0.222896      1.041637
# 1      0.247911      1.264191
# 2      0.316675      0.584028
# 3      0.231559      1.191243
# 4      0.218086      1.075741

# %% [markdown]
# ## 5. Distribution of each metric across worlds, per scorer

# %%
bootstrap_metrics.groupby("scorer").agg(["mean", "std"])
# Out:
#                      sim_id                  CAGR           Sharpe_Ratio  \
#                        mean         std      mean       std         mean
# scorer
# QQQ                   499.5  288.819436  0.107305  0.128902     0.661985
# SPY                   499.5  288.819436  0.096872  0.093331     0.746493
# geometric_drift_126d  499.5  288.819436  0.108114  0.142221     0.595924
# geometric_drift_252d  499.5  288.819436  0.149554  0.149437     0.784838
#
#                                Sortino_Ratio           Max_Drawdown            \
#                            std          mean       std         mean       std
# scorer
# QQQ                   0.627144      1.122375  1.070083     0.312286  0.100905
# SPY                   0.617096      1.258681  1.053990     0.234571  0.077408
# geometric_drift_126d  0.600466      1.047376  1.063017     0.322323  0.091253
# geometric_drift_252d  0.621405      1.378025  1.118423     0.293164  0.083753
#
#                      Calmar_Ratio
#                              mean       std
# scorer
# QQQ                      0.489955  0.607868
# SPY                      0.560993  0.603252
# geometric_drift_126d     0.454448  0.603495
# geometric_drift_252d     0.657652  0.740024

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

fig, ax = plt.subplots(figsize=(9, 5))
sns.histplot(
    data=bootstrap_metrics, x="CAGR", hue="scorer",
    stat="density", common_norm=False, kde=True,
    element="step", alpha=0.25, ax=ax,
)
ax.axvline(0, color="black", linewidth=1, linestyle="--")
ax.set_title(f"CAGR distribution across {NUM_SIMULATIONS} bootstrap worlds, per scorer")
plt.show()

# %%
# bootstrap_metrics

# %% [markdown]
# ## 6. Is each scorer significantly different from the benchmarks?
#
# `sim_id` pairs every scorer with SPY/QQQ on the SAME synthetic world, so
# this is a paired-samples question, not independent-samples -- an unpaired
# test would throw away that pairing and understate power. `src2.bootstrap_significance`
# (built on the paired-test helpers already in `src/stat_test.py`) reports,
# per scorer x benchmark x metric:
#
# - `win_rate` / `ci_2.5`-`ci_97.5`: assumption-free -- fraction of worlds
#   the scorer beat the benchmark in, and the empirical 95% CI of the
#   per-world difference. This is the number to lead with.
# - `p_value` / `significant_at_5pct`: `stat_test.automated_paired_test`
#   picks a paired t-test or Wilcoxon signed-rank test per Shapiro
#   normality check on the differences, as a formal cross-check.

# %%
from src2 import bootstrap_significance

scorer_names = list(SCORER_CONFIGS.keys())

sig_results = bootstrap_significance.compare_all(
    bootstrap_metrics,
    scorers=scorer_names,
    benches=bench_tickers,
)

# %%
sig_results.columns
# Out:
# Index(['scorer', 'bench', 'metric', 'n_sims', 'mean_diff', 'median_diff',
#        'win_rate', 'ci_2.5', 'ci_97.5', 'test_name', 'statistic', 'p_value',
#        'significant_at_5pct'],
#       dtype='str')

# %%
sig_results[sig_results["metric"] == "CAGR"][
    ["scorer", "bench", "win_rate", "mean_diff", "ci_2.5", "ci_97.5", "test_name", "p_value", "significant_at_5pct"]
].sort_values(["scorer", "bench"])
# Out:
#                   scorer bench  win_rate  mean_diff    ci_2.5   ci_97.5  \
# 5   geometric_drift_126d   QQQ     0.474   0.000809 -0.176380  0.197868
# 0   geometric_drift_126d   SPY     0.499   0.011242 -0.152495  0.224213
# 15  geometric_drift_252d   QQQ     0.658   0.042249 -0.146541  0.249180
# 10  geometric_drift_252d   SPY     0.678   0.052682 -0.122967  0.272080
#
#                     test_name       p_value  significant_at_5pct
# 5   Wilcoxon Signed-Rank Test  5.614439e-01                False
# 0   Wilcoxon Signed-Rank Test  4.407864e-02                 True
# 15  Wilcoxon Signed-Rank Test  2.260664e-33                 True
# 10  Wilcoxon Signed-Rank Test  4.515264e-47                 True

# %%
bootstrap_significance.compare_scorer_vs_benchmark(bootstrap_metrics, 'QQQ', 'SPY', 'CAGR')
# Out:
# {'scorer': 'QQQ',
#  'bench': 'SPY',
#  'metric': 'CAGR',
#  'n_sims': 1000,
#  'mean_diff': np.float64(0.010433027786588195),
#  'median_diff': np.float64(0.00721904305067772),
#  'win_rate': np.float64(0.557),
#  'ci_2.5': np.float64(-0.07548117875415117),
#  'ci_97.5': np.float64(0.11904244141054131),
#  'test_name': 'Wilcoxon Signed-Rank Test',
#  'statistic': np.float64(200479.0),
#  'p_value': np.float64(5.092389586085282e-08),
#  'significant_at_5pct': np.True_}

# %% [markdown]
# ### 6b. One-sided: did the scorer beat the benchmark? (not just "differ from it")
#
# `compare_scorer_vs_benchmark_one_sided` / `compare_all_one_sided` test
# H1: scorer > bench directly (`alternative="greater"`), which is what
# "does this scorer actually beat SPY/QQQ" really is -- a one-sided test
# has more power for that directional question than the two-sided test in
# section 6, at the same significance threshold.

# %%
reload(bootstrap_significance)
# Out:
# <module 'src2.bootstrap_significance' from '/Users/zhigangyu/Documents/codes/stock_simulation_system/src2/../src2/bootstrap_significance.py'>

# %%
sig_results_one_sided = bootstrap_significance.compare_all_one_sided(
    bootstrap_metrics,
    scorers=scorer_names,
    benches=bench_tickers,
    alternative="greater",
)

sig_results_one_sided[sig_results_one_sided["metric"] == "CAGR"][
    ["scorer", "bench", "win_rate", "mean_diff", "test_name", "p_value", "significant_at_5pct"]
].sort_values(["scorer", "bench"])
# Out:
#                   scorer bench  win_rate  mean_diff  \
# 5   geometric_drift_126d   QQQ     0.474   0.000809
# 0   geometric_drift_126d   SPY     0.499   0.011242
# 15  geometric_drift_252d   QQQ     0.658   0.042249
# 10  geometric_drift_252d   SPY     0.678   0.052682
#
#                                          test_name       p_value  \
# 5   Wilcoxon Signed-Rank Test (one-sided, greater)  7.192780e-01
# 0   Wilcoxon Signed-Rank Test (one-sided, greater)  2.203932e-02
# 15  Wilcoxon Signed-Rank Test (one-sided, greater)  1.130332e-33
# 10  Wilcoxon Signed-Rank Test (one-sided, greater)  2.257632e-47
#
#     significant_at_5pct
# 5                 False
# 0                  True
# 15                 True
# 10                 True

# %%
bootstrap_significance.compare_scorer_vs_benchmark(bootstrap_metrics, 'QQQ', 'SPY', 'CAGR')
# Out:
# {'scorer': 'QQQ',
#  'bench': 'SPY',
#  'metric': 'CAGR',
#  'n_sims': 1000,
#  'mean_diff': np.float64(0.010433027786588195),
#  'median_diff': np.float64(0.00721904305067772),
#  'win_rate': np.float64(0.557),
#  'ci_2.5': np.float64(-0.07548117875415117),
#  'ci_97.5': np.float64(0.11904244141054131),
#  'test_name': 'Wilcoxon Signed-Rank Test',
#  'statistic': np.float64(200479.0),
#  'p_value': np.float64(5.092389586085282e-08),
#  'significant_at_5pct': np.True_}

# %%
wide = bootstrap_metrics.pivot(index="sim_id", columns="scorer", values='CAGR')
scorer='QQQ'
bench='SPY'
stat_test.automated_paired_test_one_sided(wide[scorer], wide[bench], alternative='greater')
# Out:
# {'test_name': 'Wilcoxon Signed-Rank Test (one-sided, greater)',
#  'statistic': np.float64(300021.0),
#  'p_value': np.float64(2.546194793042641e-08),
#  'significant_at_5pct': np.True_}

# %% [markdown]
# ## 7. Conditional performance: does each scorer's edge depend on the market regime?
#
# Sections 6/6b pool all worlds into one win-rate/p-value. That averages away
# the more useful question: a mean-reversion scorer that wins in choppy
# markets and loses in trending ones could pool to a mediocre-looking
# average despite having a real, strong conditional edge. Classify each
# world's regime from its benchmark's raw price path (no backtest needed --
# see notes/stationary_bootstrap.md section 5 for why R² of a log-price
# trend fit, not just net return), then rerun the paired comparison *within*
# each regime.
#
# Two passes, since "bull/bear" is only meaningful relative to the spread of
# outcomes across all worlds:
# 1. `classify_world_regime` per sim_id -- cheap (just an OLS fit), plain loop.
# 2. `label_regimes` buckets by tercile of total_return (direction) and R²
#    threshold (trending vs. choppy) across the whole population at once.

# %%
reload(bootstrap_compare)

REGIME_TICKER = 'SPY'

trend_features = pd.DataFrame([
    bootstrap_compare.classify_world_regime(
        sim_id, price_tensor[sim_id], dates_index, eng_tickers,
        regime_ticker=REGIME_TICKER, warmup_days=WARMUP_DAYS,
    )
    for sim_id in range(NUM_SIMULATIONS)
])

world_regimes = bootstrap_compare.label_regimes(trend_features)
world_regimes['regime'].value_counts()
# Out:
# regime
# choppy        562
# bull_trend    421
# bear_trend     17
# Name: count, dtype: int64

# %%
bootstrap_metrics_regime = bootstrap_metrics.merge(
    world_regimes[['sim_id', 'regime', 'total_return', 'r2']], on='sim_id', how='left'
)

conditional_results = pd.concat([
    bootstrap_significance.compare_all(
        bootstrap_metrics_regime[bootstrap_metrics_regime['regime'] == regime],
        scorers=scorer_names,
        benches=bench_tickers,
        metrics=['CAGR'],
    ).assign(regime=regime)
    for regime in world_regimes['regime'].unique()
], ignore_index=True)

conditional_results[
    ['regime', 'scorer', 'bench', 'n_sims', 'win_rate', 'mean_diff', 'p_value', 'significant_at_5pct']
].sort_values(['scorer', 'bench', 'regime'])
# Out:
#         regime                scorer bench  n_sims  win_rate  mean_diff  \
# 9   bear_trend  geometric_drift_126d   QQQ      17  0.764706   0.049977
# 5   bull_trend  geometric_drift_126d   QQQ     421  0.377672  -0.020210
# 1       choppy  geometric_drift_126d   QQQ     562  0.537367   0.015067
# 8   bear_trend  geometric_drift_126d   SPY      17  0.352941  -0.004985
# 4   bull_trend  geometric_drift_126d   SPY     421  0.505938   0.012225
# 0       choppy  geometric_drift_126d   SPY     562  0.498221   0.010996
# 11  bear_trend  geometric_drift_252d   QQQ      17  0.882353   0.089136
# 7   bull_trend  geometric_drift_252d   QQQ     421  0.608076   0.032554
# 3       choppy  geometric_drift_252d   QQQ     562  0.688612   0.048093
# 10  bear_trend  geometric_drift_252d   SPY      17  0.529412   0.034173
# 6   bull_trend  geometric_drift_252d   SPY     421  0.700713   0.064989
# 2       choppy  geometric_drift_252d   SPY     562  0.665480   0.044022
#
#          p_value  significant_at_5pct
# 9   4.945636e-03                 True
# 5   2.968338e-06                 True
# 1   2.329458e-03                 True
# 8   7.453597e-01                False
# 4   1.319234e-01                False
# 0   1.478349e-01                False
# 11  1.114537e-04                 True
# 7   1.416622e-08                 True
# 3   4.654401e-26                 True
# 10  2.434998e-01                False
# 6   7.844449e-26                 True
# 2   2.225444e-22                 True

# %%
scorer_names_check=['geometric_drift_252d','QQQ','SPY']

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.boxplot(
    data=bootstrap_metrics_regime[bootstrap_metrics_regime['scorer'].isin(scorer_names_check)],
    x='regime', y='CAGR', hue='scorer', ax=ax,
)
ax.axhline(0, color='black', linewidth=1, linestyle='--')
ax.set_title('CAGR by scorer, conditioned on regime')
plt.show()

# %%
conditional_results.columns
# Out:
# Index(['scorer', 'bench', 'metric', 'n_sims', 'mean_diff', 'median_diff',
#        'win_rate', 'ci_2.5', 'ci_97.5', 'test_name', 'statistic', 'p_value',
#        'significant_at_5pct', 'regime'],
#       dtype='str')

# %%
conditional_results.loc[conditional_results['regime']=='choppy',['scorer','bench','significant_at_5pct','mean_diff','median_diff','win_rate']]
# Out:
#                  scorer bench  significant_at_5pct  mean_diff  median_diff  \
# 0  geometric_drift_126d   SPY                False   0.010996    -0.001210
# 1  geometric_drift_126d   QQQ                 True   0.015067     0.006844
# 2  geometric_drift_252d   SPY                 True   0.044022     0.034112
# 3  geometric_drift_252d   QQQ                 True   0.048093     0.040100
#
#    win_rate
# 0  0.498221
# 1  0.537367
# 2  0.665480
# 3  0.688612

# %%
conditional_results.loc[conditional_results['regime']=='bull_trend',['scorer','bench','significant_at_5pct','mean_diff','median_diff','win_rate']]
# Out:
#                  scorer bench  significant_at_5pct  mean_diff  median_diff  \
# 4  geometric_drift_126d   SPY                False   0.012225     0.001766
# 5  geometric_drift_126d   QQQ                 True  -0.020210    -0.025772
# 6  geometric_drift_252d   SPY                 True   0.064989     0.055291
# 7  geometric_drift_252d   QQQ                 True   0.032554     0.025051
#
#    win_rate
# 4  0.505938
# 5  0.377672
# 6  0.700713
# 7  0.608076

# %% [markdown]
# ### 7b. Peek at one world per regime
#
# `world_regimes` already carries `sim_id` alongside `regime` (it flows
# straight through from `classify_world_regime`'s dict), so
# `world_regimes[world_regimes['regime'] == 'choppy']['sim_id']` works
# directly -- `bootstrap_compare.sample_sim_ids_per_regime` just wraps that
# filter and, by default, picks the most extreme example of each regime
# (highest total_return for bull_trend, lowest for bear_trend, lowest r2 for
# choppy) rather than a borderline case near a tercile/R² cutoff.

# %%
example_sim_ids = bootstrap_compare.sample_sim_ids_per_regime(world_regimes,n_per_regime=10)
example_sim_ids
# Out:
# {'bear_trend': [236, 644, 294, 777, 803, 465, 404, 418, 382, 798],
#  'bull_trend': [46, 411, 646, 149, 804, 141, 490, 82, 688, 110],
#  'choppy': [586, 951, 715, 361, 234, 445, 965, 637, 936, 67]}

# %%
# for regime, sim_ids in example_sim_ids.items():
regime='choppy'
sim_ids=example_sim_ids[regime]
peek_sim_id = sim_ids[4]
df_nav_peek = bootstrap_compare.build_world_nav(
    peek_sim_id,
    price_tensor[peek_sim_id],
    volume_tensor[peek_sim_id],
    dates_index,
    eng_tickers,
    eng_rebalance_dates,
    SCORER_CONFIGS,
    bench_tickers,
    warmup_days=WARMUP_DAYS
)
print(f"regime={regime}  sim_id={peek_sim_id}")
analysis.plot_rebased_performance(df_nav_peek)
# Out:
# regime=choppy  sim_id=234

# %%
re
