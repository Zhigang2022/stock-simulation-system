# %%
import sys
from pathlib import Path
project_root = Path().resolve().parent  
project_root
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
import numpy as np
np.random.seed(42)

# %%
from importlib import reload

# %%
import pandas as pd
from tqdm import tqdm

# %%
from src import data_broker
from src import statioinary_bootstrap
from src import global_state

from src import calendar_iterator
from src import strategy_selector, ad_hoc_strategy

from src import executor_module, performance_evaluator
from src import compliance_filters, budget_allocator
from src import audit

from src import signal_schema
from src import metrics

from src import logging

# %%
reload(strategy_selector)
# Out:
# <module 'src.strategy_selector' from '/Users/zhigangyu/Documents/Project Z/src/strategy_selector.py'>

# %%
logger=logging.setup_logger(name="backtest_logger", log_file="backtest.log")

# %%
import ticker_loader
totak_tickers=ticker_loader.load_total_tickers()
# tickers=run2.get_random_sample(totak_tickers,30)

# %%
# 动量亏本 组合
# ','.join(tickers)
# tickers='ALGN,AAPL,PANW,AMD,ZS,MDLZ,XEL,VRSN,INSM,ON,WDAY,ENPH,DLTR,ADI,COST,ABNB,CEG,MSFT,GOOGL,CDNS,PYPL,FAST,JD,MTCH,SNPS,LULU,CMCSA,ADBE,ADSK'.split(',')

# %%
# tickers=['SPY','QQQ','QQQE','IWM','XSW','XLY','XLV','XLU','XLRE','XLP','XLK','XLI','XLF','XLE','XLC','XLB','LABU','XBI']#,'VXX']

# %%
tickers=totak_tickers

# %%
broker = data_broker.DataBroker(tickers=tickers, start_date="2022-01-01", end_date="2026-04-01")
universe_data = broker.fetch_universe_data()
# Out:
# [************          25%                       ]  28 of 112 completed$ATVI: possibly delisted; no timezone found
# [******************    38%                       ]  43 of 112 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# $WBA: possibly delisted; no timezone found
# [**********************50%                       ]  56 of 112 completed$ANSS: possibly delisted; no timezone found
# [**********************62%*****                  ]  70 of 112 completed$SPLK: possibly delisted; no timezone found
# [**********************69%********               ]  77 of 112 completed$SGEN: possibly delisted; no timezone found
# [**********************80%*************          ]  90 of 112 completed$FI: possibly delisted; no timezone found
# [**********************98%********************** ]  110 of 112 completed$XLNX: possibly delisted; no timezone found
# [*********************100%***********************]  112 of 112 completed
#
# 7 Failed downloads:
# ['ATVI', 'WBA', 'ANSS', 'SPLK', 'SGEN', 'FI', 'XLNX']: possibly delisted; no timezone found

# %%
universe_data=ticker_loader.fix_data(universe_data)
# Out:
# price shape before drop: (1064, 112)
# price shape after drop: (1064, 105)
# volume shape after drop: (1064, 105)

# %%
bench_tickers=['SPY','QQQ']
bench_broker = data_broker.DataBroker(tickers=bench_tickers, start_date="2022-01-01", end_date="2026-04-01")
bench_universe_data = bench_broker.fetch_universe_data()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# adhoc_exit=ad_hoc_strategy.AdHocChandelierExit()

# %%
reload(strategy_selector)
# Out:
# <module 'src.strategy_selector' from '/Users/zhigangyu/Documents/Project Z/src/strategy_selector.py'>

# %%
risk_adj_moment=strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.SimpleRiskAdjustedScorer(),
    long_window=252,
    short_window=21,
    structural_weight=.6
)

linear_strategy = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.TraditionalLinearRegressionScorer(),
    long_window=252,
    short_window=21,
    structural_weight=.6
)

# Configuration A: Advanced Risk-Adjusted Blended Momentum
advanced_risk_strat = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.GeometricDriftScorer(),
    long_window=252,
    short_window=21,
    structural_weight=.6
)

# Configuration B: Advanced Information Discrete Momentum (Time-Weighted)
advanced_info_strat = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.WeightedLinearRegressionScorer(decay_factor=0.97),
    long_window=252,
    short_window=21,
    structural_weight=.6
)

# %%
#126, 10

# %%
strategies={'simple_risk':risk_adj_moment,
            'linear_strategy':linear_strategy,
            'advanced_risk_strat':advanced_risk_strat,
            'advanced_info_strat':advanced_info_strat,}

# %%
portfolio_filter=compliance_filters.LiquidityComplianceFilter()

# %% [markdown]
# # run only on the real data

# %%
def run(module_c_regular,module_c1_adhoc=None,is_filter=True,allocation_type='score_weighted'):
    allocator=budget_allocator.IntegratedBudgetAllocator(top_percent=.10, allocation_type=allocation_type)
    g_state=global_state.GlobalState(initial_capital=100_000,core_allocation_pct=1.0)
    executor=executor_module.TransactionExecutor(trade_delay=1)
    calendar = calendar_iterator.CalendarIterator(world_data_dict, interval="ME")
    rebalance_dates = calendar.generate_rebalance_dates()
    
    
    
    # Initialize a formal ledger
    audit_ledger: list[audit.AuditRecord] = []
    logger.info("Initializing Backtest Engine...")
    
    for i, today in enumerate(world_data_dict['price'].index):
        snapshot = calendar.get_historical_snapshot(today)
        market_prices = snapshot['price'].loc[today]
        
        # Initialize containers for this specific time-step's audit trail
        current_telemetry = signal_schema.StrategyTelemetry()
        g_state.signals.clear_signals()
        
        # 1. Strategy Calculation Pass
        regular_strategy_output,adhoc_strategy_output=None, None
        raw_regular_signals,filtered_regular_signals=[],[]
        if today in rebalance_dates and (module_c_regular is not None):
            # Update your strategy to return the StrategyTelemetry object instead of loose info dicts
            regular_strategy_output, current_telemetry = module_c_regular.calculate_signals(snapshot)
            raw_regular_signals = list(regular_strategy_output.signals)
            if is_filter:
                regular_strategy_output = portfolio_filter.filter_signals(today, regular_strategy_output, snapshot)
                filtered_regular_signals=list(regular_strategy_output.signals)
            else:
                filtered_regular_signals=raw_regular_signals
    
            if regular_strategy_output.signals:
                logger.info(f"=== REBALANCE EVENT TRIGGERED: {today.strftime('%Y-%m-%d')} ===")
    
        raw_adhoc_signals,filtered_adhoc_signals=[],[]
        if module_c1_adhoc is not None:
            adhoc_strategy_output = module_c1_adhoc.evaluate_exits(g_state, snapshot)
            raw_adhoc_signals= list(adhoc_strategy_output.signals)
            adhoc_strategy_output = portfolio_filter.filter_signals(today, adhoc_strategy_output, snapshot)
            filtered_adhoc_signals=list(adhoc_strategy_output.signals)
        g_state.signals.update_signals(regular_strategy_output,adhoc_strategy_output)
        
    
        # 2. Allocation Pass
        core_target_weights, sell_adhoc_orders, buy_adhoc_orders = allocator.allocate_capital(
             g_state, market_prices,
        ) 
        
        
        g_state.need_trade.set_core(core_target_weights, today)
        g_state.need_trade.set_sell_adhoc(sell_adhoc_orders, today)
        g_state.need_trade.set_buy_adhoc(buy_adhoc_orders, today)
        
        # 3. Execution & Portfolio State Capture
        # (Capture the current trades before or during execution context if needed)
        executor.execute_trades(g_state, today, market_prices)
        g_state.record_daily_snapshot(today, market_prices)
        
        # 4. Commit to Audit Ledger only on actionable days to save memory, 
        # or every day depending on your debugging requirements
        if today in rebalance_dates and len(getattr(current_telemetry,'metrics',{}))!=0:
            
            audit_ledger.append(audit.AuditRecord(
                date=today,
                telemetry=current_telemetry,
                raw_regular_signals=raw_regular_signals,
                filtered_regular_signals=filtered_regular_signals,
                raw_adhoc_signals=raw_adhoc_signals,
                filtered_adhoc_signals=filtered_adhoc_signals,
                target_weights=core_target_weights,
                executed_trades=[] # Populate from executor if your executor keeps track
            ))
    
    logger.info("Backtest execution completed successfully.")
    return g_state

# %%
world_data_dict= universe_data

# %%
reload(executor_module)
# Out:
# <module 'src.executor_module' from '/Users/zhigangyu/Documents/Project Z/src/executor_module.py'>

# %%
states={}
for strat_name in strategies:
    print(f'******* {strat_name} *******')
    strategy=strategies[strat_name]
    state=run(strategy)#,allocation_type='score_weighted')
    states[strat_name]=state
# Out:
# ******* simple_risk *******
# [2026-07-07 10:21:13] INFO [backtest_logger]: Initializing Backtest Engine...
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-07-29 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ADP ... 40.36@220.32, fee: 8.9
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ENPH ... 33.27@280.89, fee: 9.35
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY MNST ... 178.71@49.24, fee: 8.81
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY SMCI ... 1576.72@5.52, fee: 8.72
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY SNPS ... 25.5@370.01, fee: 9.45
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY CTAS ... 90.59@102.16, fee: 9.26
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY CDNS ... 51.48@185.04, fee: 9.54
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY PAYX ... 80.56@111.49, fee: 8.99
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY AEP ... 107.04@85.61, fee: 9.17
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY TRI ... 88.2@102.87, fee: 9.08
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ON ... 135.39@63.66, fee: 8.63
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-08-31 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL ADP ... 40.36@224.56, fee: 9.06
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL SMCI ... 136.64@6.33, fee: 0.86
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL SNPS ... 25.5@332.49, fee: 8.48
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL CTAS ... 90.59@98.47, fee: 8.92
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL CDNS ... 51.48@170.04, fee: 8.75
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL PAYX ... 80.56@110.1, fee: 8.87
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL AEP ... 107.04@89.13, fee: 9.54
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL TRI ... 88.2@102.22, fee: 9.02
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL ON ... 4.41@68.22, fee: 0.3
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY ENPH ... 0.04@281.86, fee: 0.01
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY MNST ... 13.95@44.5, fee: 0.62
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY CEG ... 117.88@80.16, fee: 9.46
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY INSM ... 346.55@25.19, fee: 8.74
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY NTES ... 109.65@80.43, fee: 8.83
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY GILD ... 152.59@56.62, fee: 8.65
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY PDD ... 129.79@71.42, fee: 9.28
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY TMUS ... 66.7@137.63, fee: 9.19
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY VRTX ... 31.01@290.2, fee: 9.01
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-09-30 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL ENPH ... 4.76@286.61, fee: 1.36
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL CEG ... 117.88@84.11, fee: 9.92
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL INSM ... 346.55@22.16, fee: 7.68
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL NTES ... 109.65@69.78, fee: 7.65
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL GILD ... 152.59@54.94, fee: 8.38
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL TMUS ... 66.7@132.83, fee: 8.86
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL ON ... 130.98@64.79, fee: 8.49
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL VRTX ... 0.9@297.43, fee: 0.27
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY TTD ... 136.26@61.13, fee: 8.34
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY MNST ... 0.73@44.53, fee: 0.03
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY CSGP ... 118.09@71.99, fee: 8.51
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY SMCI ... 83.89@5.71, fee: 0.48
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY ORLY ... 182.94@47.88, fee: 8.77
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY CDNS ... 49.42@170.28, fee: 8.42
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY REGN ... 11.31@729.11, fee: 8.25
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY PDD ... 11.77@62.65, fee: 0.74
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY BIIB ... 34.11@264.3, fee: 9.03
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-10-31 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL TTD ... 136.26@53.08, fee: 7.23
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL MNST ... 193.39@47.17, fee: 9.12
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL CSGP ... 18.74@81.19, fee: 1.52
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL SMCI ... 355.85@7.19, fee: 2.56
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL ORLY ... 27.5@55.6, fee: 1.53
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL CDNS ... 49.42@150.93, fee: 7.46
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL REGN ... 11.31@753.68, fee: 8.52
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL PDD ... 141.56@53.89, fee: 7.63
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL BIIB ... 34.11@280.04, fee: 9.55
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL VRTX ... 30.11@314.2, fee: 9.46
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY NFLX ... 283.38@28.67, fee: 8.13
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY ISRG ... 31.42@246.86, fee: 7.76
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY ENPH ... 0.04@299.48, fee: 0.01
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY HON ... 42.51@185.34, fee: 7.89
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY CEG ... 91.12@92.79, fee: 8.46
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY PCAR ... 139.23@55.71, fee: 7.76
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY GILD ... 118.52@69.95, fee: 8.3
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY TMUS ... 56.36@145.62, fee: 8.22
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY AMGN ... 32.9@241.98, fee: 7.97
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-11-30 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL NFLX ... 283.38@31.69, fee: 8.98
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL ISRG ... 31.42@274.49, fee: 8.62
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL ENPH ... 28.59@314.0, fee: 8.98
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL HON ... 42.51@199.36, fee: 8.48
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL CSGP ... 99.35@82.95, fee: 8.24
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL PCAR ... 139.23@61.1, fee: 8.51
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL SMCI ... 98.04@9.05, fee: 0.89
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL TMUS ... 56.36@145.17, fee: 8.18
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL AMGN ... 32.9@256.08, fee: 8.43
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY SBUX ... 102.72@94.95, fee: 9.76
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY CEG ... 9.55@91.91, fee: 0.88
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY PEP ... 57.9@165.15, fee: 9.57
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY ORLY ... 17.37@57.15, fee: 0.99
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY KHC ... 280.88@32.85, fee: 9.24
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY GILD ... 10.16@77.49, fee: 0.79
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY PDD ... 113.04@83.74, fee: 9.48
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY KDP ... 268.81@34.86, fee: 9.38
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY TRI ... 83.27@109.09, fee: 9.09
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY ROST ... 88.51@113.43, fee: 10.05
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-12-30 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL SBUX ... 5.83@92.61, fee: 0.54
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL CEG ... 100.67@79.69, fee: 8.02
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL PEP ... 57.9@159.38, fee: 9.23
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL KHC ... 21.83@33.92, fee: 0.74
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL GILD ... 128.68@75.91, fee: 9.77
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL PDD ... 113.04@84.53, fee: 9.56
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL KDP ... 268.81@32.01, fee: 8.61
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL TRI ... 83.27@107.29, fee: 8.93
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL ROST ... 2.34@111.65, fee: 0.26
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY NFLX ... 306.47@29.5, fee: 9.05
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY HON ... 48.34@196.52, fee: 9.51
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY PCAR ... 158.85@58.36, fee: 9.28
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY SMCI ... 55.0@8.39, fee: 0.46
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY ORLY ... 0.51@56.05, fee: 0.03
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY CTAS ... 83.95@108.77, fee: 9.14
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY VRSN ... 46.61@198.9, fee: 9.28
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY AVGO ... 167.95@52.72, fee: 8.86
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-01-31 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL NFLX ... 306.47@36.2, fee: 11.09
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL HON ... 48.34@189.57, fee: 9.16
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL PCAR ... 16.85@66.02, fee: 1.11
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL SMCI ... 1125.08@7.97, fee: 8.97
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL ORLY ... 173.31@53.86, fee: 9.33
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL KHC ... 259.05@33.72, fee: 8.74
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL CTAS ... 83.95@108.13, fee: 9.08
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL VRSN ... 3.93@217.43, fee: 0.85
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL ROST ... 86.17@114.25, fee: 9.84
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL AVGO ... 167.95@57.42, fee: 9.64
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY SBUX ... 3.57@101.03, fee: 0.36
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY BKNG ... 103.63@95.79, fee: 9.94
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY MAR ... 57.15@169.5, fee: 9.7
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY REGN ... 12.88@751.79, fee: 9.7
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY PDD ... 88.91@102.98, fee: 9.17
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY MELI ... 8.1@1214.29, fee: 9.84
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY CSCO ... 213.67@44.2, fee: 9.45
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY WDAY ... 51.48@185.33, fee: 9.55
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY VRTX ... 31.59@317.27, fee: 10.03
# [2026-07-07 10:21:13] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-02-28 ===
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL SBUX ... 100.45@93.63, fee: 9.41
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL BKNG ... 5.73@99.97, fee: 0.57
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL MAR ... 57.15@164.16, fee: 9.38
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL REGN ... 0.44@764.13, fee: 0.34
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL PDD ... 88.91@91.04, fee: 8.09
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL MELI ... 0.08@1208.72, fee: 0.09
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL CSCO ... 10.28@43.99, fee: 0.45
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL VRSN ... 42.68@193.34, fee: 8.25
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL WDAY ... 51.48@184.12, fee: 9.48
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL VRTX ... 31.59@291.23, fee: 9.2
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY PCAR ... 5.27@65.19, fee: 0.34
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY SMCI ... 920.27@10.2, fee: 9.4
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY NVDA ... 409.89@22.67, fee: 9.3
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY ADI ... 52.32@174.09, fee: 9.12
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY AMAT ... 77.37@114.12, fee: 8.84
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY AVGO ... 159.43@56.54, fee: 9.02
# [2026-07-07 10:21:13] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY CPRT ... 263.64@34.9, fee: 9.21
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-03-31 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL SMCI ... 920.27@11.27, fee: 10.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL REGN ... 12.44@819.42, fee: 10.2
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL NVDA ... 34.77@27.94, fee: 0.97
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL MELI ... 0.46@1313.64, fee: 0.61
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL ADI ... 1.01@186.61, fee: 0.19
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL CSCO ... 203.4@47.61, fee: 9.68
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL AMAT ... 77.37@119.05, fee: 9.21
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL AVGO ... 159.43@61.64, fee: 9.83
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY BKNG ... 1.54@104.39, fee: 0.16
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY PCAR ... 5.03@65.18, fee: 0.33
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY AZN ... 77.03@131.76, fee: 10.16
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY ORLY ... 166.72@57.86, fee: 9.66
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY GILD ... 130.49@74.7, fee: 9.76
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY MDLZ ... 156.91@64.04, fee: 10.06
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY TRI ... 83.74@122.39, fee: 10.26
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY CPRT ... 16.72@37.74, fee: 0.63
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-04-28 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL BKNG ... 6.77@105.4, fee: 0.71
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL PCAR ... 152.3@66.74, fee: 10.16
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL AZN ... 77.03@138.52, fee: 10.67
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL ORLY ... 166.72@61.97, fee: 10.33
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL GILD ... 130.49@73.07, fee: 9.53
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL MDLZ ... 3.6@70.43, fee: 0.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL NVDA ... 19.13@28.88, fee: 0.55
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL MELI ... 7.56@1291.65, fee: 9.76
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL ADI ... 51.31@173.55, fee: 8.9
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL TRI ... 2.96@123.47, fee: 0.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL CPRT ... 10.18@39.2, fee: 0.4
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY SBUX ... 100.83@105.75, fee: 10.67
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY ISRG ... 32.48@303.02, fee: 9.85
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY CMCSA ... 292.37@34.72, fee: 10.16
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY MNST ... 182.18@56.84, fee: 10.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY META ... 43.38@241.06, fee: 10.47
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY MSFT ... 33.73@297.85, fee: 10.06
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-05-31 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL SBUX ... 100.83@90.47, fee: 9.12
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL BKNG ... 92.67@99.88, fee: 9.26
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL ISRG ... 32.48@310.54, fee: 10.09
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL CMCSA ... 292.37@32.55, fee: 9.52
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MNST ... 182.18@59.36, fee: 10.81
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL META ... 1.98@270.24, fee: 0.53
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MSFT ... 33.73@324.89, fee: 10.96
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MDLZ ... 153.31@67.13, fee: 10.29
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL NVDA ... 87.87@39.73, fee: 3.49
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL TRI ... 80.78@116.24, fee: 9.39
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL CPRT ... 37.15@43.9, fee: 1.63
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY NFLX ... 250.4@40.31, fee: 10.1
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY OKTA ... 145.11@74.69, fee: 10.85
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY SMCI ... 473.75@23.1, fee: 10.96
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY SNPS ... 23.61@454.55, fee: 10.74
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY CDNS ... 44.81@232.39, fee: 10.42
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY TEAM ... 58.15@177.26, fee: 10.32
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY WDAY ... 48.86@215.31, fee: 10.53
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY AVGO ... 145.8@75.79, fee: 11.06
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-06-30 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL NFLX ... 250.4@44.14, fee: 11.05
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL OKTA ... 145.11@69.26, fee: 10.05
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL META ... 4.53@283.53, fee: 1.28
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL SMCI ... 25.57@24.92, fee: 0.64
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL SNPS ... 23.61@434.01, fee: 10.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL CDNS ... 44.81@235.4, fee: 10.55
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL NVDA ... 268.12@42.38, fee: 11.36
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL TEAM ... 58.15@167.59, fee: 9.74
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL WDAY ... 48.86@224.59, fee: 10.97
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL AVGO ... 145.8@84.54, fee: 12.33
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY AAPL ... 59.82@189.8, fee: 11.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY AMZN ... 81.33@130.22, fee: 10.6
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY PCAR ... 139.21@74.89, fee: 10.44
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY FTNT ... 147.69@74.66, fee: 11.04
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY PANW ... 84.89@127.32, fee: 10.82
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY MDB ... 27.33@411.42, fee: 11.26
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY FAST ... 393.89@27.16, fee: 10.71
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY ALGN ... 31.68@344.59, fee: 10.93
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY CPRT ... 21.7@45.12, fee: 0.98
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-07-31 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL AMZN ... 81.33@131.69, fee: 10.71
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL PCAR ... 139.21@77.39, fee: 10.77
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL META ... 1.98@319.9, fee: 0.63
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL SMCI ... 90.01@33.76, fee: 3.04
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL FTNT ... 147.69@78.03, fee: 11.52
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL PANW ... 84.89@126.58, fee: 10.75
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL MDB ... 27.33@424.57, fee: 11.6
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL ALGN ... 31.68@376.62, fee: 11.93
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL CPRT ... 254.73@44.42, fee: 11.32
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY AAPL ... 3.46@192.91, fee: 0.67
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY GOOG ... 87.8@130.74, fee: 11.49
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY GOOGL ... 88.92@130.39, fee: 11.61
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY LRCX ... 171.35@69.69, fee: 11.95
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY CRWD ... 283.63@41.49, fee: 11.78
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY ADBE ... 20.69@549.1, fee: 11.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY AMAT ... 73.96@148.93, fee: 11.03
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY FAST ... 38.43@27.29, fee: 1.05
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY WDAY ... 46.9@239.8, fee: 11.26
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-08-31 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL AAPL ... 2.4@187.09, fee: 0.45
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL GOOG ... 1.27@135.6, fee: 0.17
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL META ... 34.89@293.8, fee: 10.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL GOOGL ... 2.5@134.47, fee: 0.34
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL LRCX ... 171.35@68.33, fee: 11.71
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL CRWD ... 283.63@40.31, fee: 11.43
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL AMAT ... 73.96@150.58, fee: 11.14
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL FAST ... 432.33@26.8, fee: 11.59
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL WDAY ... 46.9@248.49, fee: 11.65
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY ISRG ... 34.76@310.41, fee: 10.8
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY SMCI ... 33.36@28.22, fee: 0.94
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY NVDA ... 236.67@48.47, fee: 11.48
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY CSCO ... 204.05@53.44, fee: 10.91
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY ADBE ... 0.34@563.21, fee: 0.19
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY VRSK ... 50.14@237.85, fee: 11.94
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY INTU ... 20.86@539.14, fee: 11.26
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY AVGO ... 132.26@84.16, fee: 11.14
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-09-29 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL AAPL ... 60.89@171.58, fee: 10.45
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL ISRG ... 34.76@294.98, fee: 10.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL GOOG ... 86.53@133.99, fee: 11.59
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL GOOGL ... 86.41@132.99, fee: 11.49
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL CSCO ... 204.05@50.25, fee: 10.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL ADBE ... 21.04@521.13, fee: 10.96
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL VRSK ... 50.14@231.82, fee: 11.62
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL INTU ... 20.86@507.95, fee: 10.59
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL AVGO ... 1.69@80.98, fee: 0.14
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY COST ... 20.55@549.92, fee: 11.31
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY ZS ... 66.87@160.89, fee: 10.77
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY CEG ... 105.62@102.89, fee: 10.88
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY KLAC ... 229.27@45.03, fee: 10.33
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY META ... 36.45@304.15, fee: 11.1
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY SMCI ... 4.66@28.89, fee: 0.13
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY SNPS ... 22.96@463.82, fee: 10.66
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY NVDA ... 9.31@44.75, fee: 0.42
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY CRWD ... 246.14@42.38, fee: 10.44
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY AMGN ... 45.72@244.84, fee: 11.2
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-10-31 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL COST ... 20.55@535.95, fee: 11.02
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL ZS ... 66.87@156.65, fee: 10.48
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL CEG ... 7.43@112.83, fee: 0.84
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL KLAC ... 229.27@46.58, fee: 10.68
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL META ... 36.45@309.14, fee: 11.27
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL SMCI ... 396.2@25.23, fee: 9.99
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL SNPS ... 22.96@475.38, fee: 10.92
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL CRWD ... 246.14@44.59, fee: 10.97
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL AMGN ... 45.72@239.81, fee: 10.96
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL AVGO ... 130.57@82.72, fee: 10.8
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NFLX ... 270.65@42.02, fee: 11.38
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY AMZN ... 82.22@137.0, fee: 11.28
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY PCAR ... 143.55@74.69, fee: 10.73
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY INSM ... 422.57@24.99, fee: 10.57
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY CTAS ... 83.67@124.27, fee: 10.41
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NTES ... 110.61@100.86, fee: 11.17
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NVDA ... 4.43@42.3, fee: 0.19
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY MDB ... 32.27@339.02, fee: 10.95
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY PDD ... 105.22@102.93, fee: 10.84
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY ADBE ... 18.9@544.5, fee: 10.3
# [2026-07-07 10:21:14] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-11-30 ===
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NFLX ... 270.65@46.57, fee: 12.61
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL AMZN ... 82.22@147.03, fee: 12.09
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL CEG ... 98.19@118.05, fee: 11.59
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL PCAR ... 143.55@83.96, fee: 12.05
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL INSM ... 422.57@26.52, fee: 11.21
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL CTAS ... 83.67@136.64, fee: 11.43
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NTES ... 110.61@102.26, fee: 11.31
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NVDA ... 250.41@46.73, fee: 11.7
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL MDB ... 32.27@435.23, fee: 14.04
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL PDD ... 16.54@145.27, fee: 2.4
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL ADBE ... 18.9@612.47, fee: 11.57
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY COST ... 21.28@574.98, fee: 12.25
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY ZS ... 59.93@198.03, fee: 11.88
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY PANW ... 85.11@148.08, fee: 12.62
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY PAYX ... 102.55@113.94, fee: 11.7
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY CRWD ... 216.56@58.76, fee: 12.74
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY TMUS ... 85.34@146.23, fee: 12.49
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY ROST ... 96.13@128.55, fee: 12.37
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY WDAY ... 42.81@272.92, fee: 11.7
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY INTU ... 21.46@564.37, fee: 12.13
# [2026-07-07 10:21:14] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY LULU ... 25.7@466.61, fee: 12.0
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-12-29 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL COST ... 2.5@641.71, fee: 1.6
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL ZS ... 59.93@212.37, fee: 12.73
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PANW ... 85.11@144.46, fee: 12.29
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PAYX ... 102.55@108.38, fee: 11.11
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PDD ... 88.68@145.64, fee: 12.92
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL CRWD ... 216.56@61.72, fee: 13.37
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL TMUS ... 4.57@155.51, fee: 0.71
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL WDAY ... 42.81@268.28, fee: 11.49
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL LULU ... 0.34@505.38, fee: 0.17
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY INTC ... 276.27@47.17, fee: 13.04
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY INSM ... 409.9@29.94, fee: 12.28
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY META ... 35.38@343.28, fee: 12.16
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY CDW ... 58.32@212.6, fee: 12.41
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY CTAS ... 87.33@144.87, fee: 12.66
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY ROST ... 0.26@134.28, fee: 0.03
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY AMGN ... 48.21@275.56, fee: 13.3
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY INTU ... 0.78@593.3, fee: 0.46
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-01-31 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL COST ... 1.07@695.82, fee: 0.74
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INTC ... 276.27@42.79, fee: 11.82
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INSM ... 409.9@28.53, fee: 11.69
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL META ... 35.38@391.34, fee: 13.85
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL CDW ... 58.32@221.67, fee: 12.93
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL CTAS ... 0.61@151.15, fee: 0.09
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL TMUS ... 80.78@156.08, fee: 12.61
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL ROST ... 0.62@139.58, fee: 0.09
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL AMGN ... 2.9@300.74, fee: 0.87
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INTU ... 2.03@622.84, fee: 1.26
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL LULU ... 25.36@461.94, fee: 11.71
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY ASML ... 14.69@872.03, fee: 12.82
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY ZS ... 52.18@238.06, fee: 12.43
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY CEG ... 105.02@125.68, fee: 13.21
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY PCAR ... 136.17@95.03, fee: 12.95
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY NVDA ... 213.65@62.99, fee: 13.47
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY CRWD ... 169.44@74.84, fee: 12.69
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-02-29 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL ASML ... 14.69@972.04, fee: 14.28
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL ZS ... 52.18@219.23, fee: 11.44
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CEG ... 17.92@167.39, fee: 3.0
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CTAS ... 86.72@154.14, fee: 13.37
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL NVDA ... 213.65@82.23, fee: 17.57
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CRWD ... 169.44@78.65, fee: 13.33
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL AMGN ... 45.31@261.79, fee: 11.86
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL INTU ... 20.21@655.96, fee: 13.26
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY MU ... 146.65@94.38, fee: 13.85
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY MAR ... 54.85@244.71, fee: 13.43
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY AMZN ... 74.52@178.22, fee: 13.29
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY COST ... 2.17@740.22, fee: 1.6
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY PCAR ... 0.46@105.7, fee: 0.05
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY AMD ... 66.92@202.64, fee: 13.57
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY CSX ... 381.62@37.0, fee: 14.13
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY TMUS ... 86.97@157.54, fee: 13.71
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY FAST ... 411.0@34.7, fee: 14.27
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY ROST ... 0.31@145.94, fee: 0.05
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-03-28 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL MU ... 23.58@123.42, fee: 2.91
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL MAR ... 54.85@246.01, fee: 13.49
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL COST ... 19.88@712.37, fee: 14.16
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL CEG ... 5.89@183.5, fee: 1.08
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL PCAR ... 5.75@114.96, fee: 0.66
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL AMD ... 66.92@183.34, fee: 12.27
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL CSX ... 381.62@35.6, fee: 13.58
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL TMUS ... 86.97@156.86, fee: 13.64
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL FAST ... 28.33@36.48, fee: 1.03
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL ROST ... 96.08@141.87, fee: 13.63
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY ASML ... 14.29@974.01, fee: 13.93
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY AMZN ... 5.41@180.97, fee: 0.98
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CDW ... 57.84@244.42, fee: 14.15
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY LRCX ... 152.75@96.33, fee: 14.73
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CTAS ... 85.55@166.94, fee: 14.3
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY AVGO ... 103.73@132.11, fee: 13.72
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CPRT ... 250.91@58.07, fee: 14.58
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-04-30 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL ASML ... 14.29@838.31, fee: 11.98
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL MU ... 123.07@108.92, fee: 13.4
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL AMZN ... 79.93@179.0, fee: 14.31
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CEG ... 81.21@182.1, fee: 14.79
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL PCAR ... 130.89@99.31, fee: 13.0
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL LRCX ... 152.75@85.18, fee: 13.01
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CTAS ... 85.55@162.78, fee: 13.93
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL FAST ... 382.67@32.67, fee: 12.5
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL AVGO ... 103.73@121.61, fee: 12.61
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CPRT ... 250.91@54.44, fee: 13.66
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY EBAY ... 269.76@49.3, fee: 13.31
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY COST ... 18.8@714.48, fee: 13.44
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY KLAC ... 195.18@65.43, fee: 12.78
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY AZN ... 89.46@147.18, fee: 13.18
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY KHC ... 424.99@31.91, fee: 13.57
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY QCOM ... 82.08@157.2, fee: 12.92
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY CDW ... 2.68@207.28, fee: 0.56
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY NVDA ... 157.06@82.99, fee: 13.05
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY NXPI ... 57.12@239.72, fee: 13.71
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY ADI ... 67.28@187.86, fee: 12.65
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY TMUS ... 86.64@159.56, fee: 13.84
# [2026-07-07 10:21:15] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-05-31 ===
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL COST ... 0.13@806.66, fee: 0.1
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL KLAC ... 6.24@74.24, fee: 0.46
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL AZN ... 89.46@152.15, fee: 13.61
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL KHC ... 424.99@30.87, fee: 13.12
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL QCOM ... 5.29@198.05, fee: 1.05
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL CDW ... 60.52@216.43, fee: 13.1
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL NVDA ... 22.18@114.94, fee: 2.55
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL NXPI ... 57.12@259.43, fee: 14.82
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL ADI ... 67.28@224.99, fee: 15.14
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY ASML ... 15.36@949.03, fee: 14.59
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY NFLX ... 223.01@63.38, fee: 14.15
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY EBAY ... 16.88@52.02, fee: 0.88
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY CEG ... 70.11@205.79, fee: 14.44
# [2026-07-07 10:21:15] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY MRNA ... 99.6@147.82, fee: 14.74
# ...
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL AMD ... 19.05@171.7, fee: 3.27
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL MSFT ... 1.7@519.96, fee: 0.89
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL NTES ... 115.71@124.28, fee: 14.38
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL NVDA ... 8.68@173.69, fee: 1.51
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL MELI ... 6.51@2375.92, fee: 15.47
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL CRWD ... 127.62@111.67, fee: 14.25
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL AVGO ... 4.11@286.54, fee: 1.18
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY DLTR ... 135.72@114.72, fee: 15.59
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY CEG ... 48.32@338.99, fee: 16.4
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY INSM ... 147.72@108.69, fee: 16.07
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY SNPS ... 25.43@618.65, fee: 15.75
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY CDNS ... 44.52@356.97, fee: 15.91
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY INTU ... 21.04@770.93, fee: 16.23
# [2026-07-07 10:21:30] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-08-29 ===
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL DLTR ... 135.72@111.35, fee: 15.11
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL CEG ... 48.32@305.95, fee: 14.78
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL INSM ... 34.46@145.3, fee: 5.01
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL SMCI ... 298.64@40.78, fee: 12.18
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL SNPS ... 25.43@592.01, fee: 15.05
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL AMD ... 99.45@162.32, fee: 16.14
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL MSFT ... 29.72@501.94, fee: 14.92
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL CDNS ... 44.52@342.81, fee: 15.26
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL NVDA ... 95.51@170.75, fee: 16.31
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL INTU ... 21.04@657.54, fee: 13.83
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL AVGO ... 7.11@296.07, fee: 2.1
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY GOOG ... 76.17@211.39, fee: 16.12
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY IDXX ... 24.2@639.45, fee: 15.49
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY DDOG ... 110.26@134.69, fee: 14.87
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY GOOGL ... 77.14@210.75, fee: 16.27
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY LRCX ... 162.0@96.5, fee: 15.65
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY NTES ... 119.85@133.04, fee: 15.96
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY MDB ... 49.6@318.29, fee: 15.8
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY ADI ... 62.1@246.67, fee: 15.33
# [2026-07-07 10:21:30] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY CSCO ... 225.93@66.42, fee: 15.02
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-09-30 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL GOOG ... 76.17@245.06, fee: 18.67
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL IDXX ... 24.2@620.11, fee: 15.01
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL DDOG ... 110.26@152.7, fee: 16.84
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL INSM ... 113.26@147.28, fee: 16.68
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL GOOGL ... 77.14@244.42, fee: 18.86
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL LRCX ... 35.9@142.28, fee: 5.11
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL NTES ... 119.85@147.07, fee: 17.63
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL MDB ... 49.6@321.53, fee: 15.95
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL ADI ... 62.1@237.69, fee: 14.76
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL CSCO ... 225.93@67.36, fee: 15.22
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL AVGO ... 51.36@331.53, fee: 17.03
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY ASML ... 16.55@997.99, fee: 16.53
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY AAPL ... 68.22@254.73, fee: 17.39
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY INTC ... 502.66@35.94, fee: 18.08
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY PTON ... 2024.14@8.67, fee: 17.57
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY KLAC ... 150.0@112.41, fee: 16.88
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY EA ... 85.57@201.06, fee: 17.22
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY NVDA ... 90.98@187.22, fee: 17.05
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY XEL ... 208.17@78.52, fee: 16.36
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY FAST ... 355.37@46.96, fee: 16.71
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY TSLA ... 38.57@459.46, fee: 17.74
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-10-31 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL ASML ... 16.55@1063.09, fee: 17.59
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL AAPL ... 68.22@268.29, fee: 18.3
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL INTC ... 60.66@39.5, fee: 2.4
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL PTON ... 2024.14@7.27, fee: 14.72
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL KLAC ... 11.99@121.4, fee: 1.45
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL LRCX ... 11.94@160.67, fee: 1.92
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL EA ... 85.57@199.33, fee: 17.06
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL NVDA ... 9.13@206.86, fee: 1.89
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL XEL ... 208.17@79.45, fee: 16.54
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL FAST ... 355.37@40.6, fee: 14.43
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL TSLA ... 38.57@468.37, fee: 18.06
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY MU ... 78.75@234.47, fee: 18.48
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY GOOG ... 62.64@283.56, fee: 17.78
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY INSM ... 96.32@186.23, fee: 17.96
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY AMD ... 66.37@259.65, fee: 17.25
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY GOOGL ... 63.97@283.17, fee: 18.13
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY MDB ... 47.65@369.05, fee: 17.6
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY AVGO ... 47.31@360.53, fee: 17.08
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-11-28 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL MU ... 78.75@240.23, fee: 18.92
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL INTC ... 2.16@40.01, fee: 0.09
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL GOOG ... 4.45@314.5, fee: 1.4
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL KLAC ... 138.01@115.42, fee: 15.93
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL INSM ... 12.26@211.41, fee: 2.59
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL AMD ... 66.37@219.76, fee: 14.59
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL GOOGL ... 5.18@314.28, fee: 1.63
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL LRCX ... 5.77@154.24, fee: 0.89
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL NVDA ... 81.85@179.9, fee: 14.72
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL MDB ... 47.65@328.87, fee: 15.67
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL AVGO ... 0.56@383.93, fee: 0.22
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY IDXX ... 23.11@728.97, fee: 16.86
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY REGN ... 24.16@748.09, fee: 18.09
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY AMAT ... 67.32@254.12, fee: 17.13
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY BIIB ... 97.71@177.78, fee: 17.39
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY ROST ... 97.0@176.38, fee: 17.13
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-12-31 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL INTC ... 17.45@39.38, fee: 0.69
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL GOOG ... 0.36@314.91, fee: 0.11
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL IDXX ... 23.11@669.99, fee: 15.48
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL INSM ... 84.06@177.12, fee: 14.89
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL GOOGL ... 1.77@314.74, fee: 0.56
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL LRCX ... 11.23@184.71, fee: 2.07
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL REGN ... 2.0@774.22, fee: 1.55
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL AMAT ... 2.69@268.2, fee: 0.72
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL ROST ... 97.0@182.0, fee: 17.65
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL AVGO ... 46.75@346.34, fee: 16.19
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY ASML ... 15.2@1159.71, fee: 17.65
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY MU ... 58.15@315.24, fee: 18.35
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY MNST ... 220.07@76.16, fee: 16.78
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY AZN ... 93.43@181.25, fee: 16.95
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY BIIB ... 0.75@177.82, fee: 0.13
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-01-30 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL ASML ... 0.78@1436.35, fee: 1.12
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL MU ... 9.89@437.55, fee: 4.33
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL MNST ... 220.07@81.1, fee: 17.85
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL INTC ... 422.39@48.81, fee: 20.62
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL AZN ... 93.43@186.47, fee: 17.42
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL LRCX ... 8.92@237.05, fee: 2.11
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL REGN ... 22.16@752.99, fee: 16.69
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL AMAT ... 3.85@327.58, fee: 1.26
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GOOG ... 1.15@344.45, fee: 0.4
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY KLAC ... 136.15@140.68, fee: 19.17
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GOOGL ... 2.74@343.24, fee: 0.94
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GILD ... 137.82@141.16, fee: 19.47
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY ADI ... 63.49@315.87, fee: 20.08
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY BIIB ... 11.57@179.09, fee: 2.07
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY VRTX ... 40.58@472.01, fee: 19.17
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-02-27 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL ASML ... 0.25@1420.44, fee: 0.35
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL MU ... 0.42@412.43, fee: 0.17
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GOOG ... 58.98@305.96, fee: 18.04
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL KLAC ... 0.8@153.3, fee: 0.12
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GOOGL ... 59.76@306.12, fee: 18.3
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL LRCX ... 4.42@230.56, fee: 1.02
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GILD ... 137.82@148.21, fee: 20.43
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL ADI ... 3.28@351.31, fee: 1.15
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL AMAT ... 4.42@371.72, fee: 1.64
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL BIIB ... 110.03@188.05, fee: 20.69
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL VRTX ... 40.58@486.03, fee: 19.72
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY MNST ... 252.72@81.06, fee: 20.51
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY MRNA ... 403.0@52.85, fee: 21.32
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY CSX ... 461.84@43.04, fee: 19.9
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY ROST ... 100.67@201.48, fee: 20.3
# [2026-07-07 10:21:31] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY AMGN ... 50.86@382.81, fee: 19.49
# [2026-07-07 10:21:31] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-03-31 ===
# [2026-07-07 10:21:31] INFO [backtest_logger]: Backtest execution completed successfully.

# %% [markdown]
# # analysis

# %%
from src import analysis

# %%
def evaluate(g_state,effective_date='2023-01-01'):
    g_state.display_current_state(today,market_prices)
    df_nav=g_state.export_nav_dataframe()
    df_nav_effect=df_nav.loc[df_nav.index>='2023-01-01']
    print(metrics.calculate_metrics(df_nav_effect))
    return df_nav_effect

# %%
effective_date='2023-01-31'
bench_price=bench_universe_data['price']

# %%
df_nav_list=[]
for strat_name in states:
    print(strat_name)
    g_state=states[strat_name]
    df_nav=g_state.export_nav_dataframe()[['Total_NAV']]
    df_nav=df_nav.rename({'Total_NAV':strat_name},axis=1)
    df_nav_list.append(df_nav)
# Out:
# simple_risk
# linear_strategy
# advanced_risk_strat
# advanced_info_strat

# %%
df1=pd.concat([bench_price]+df_nav_list,axis=1)
df2=df1.loc[effective_date:]

# %%
# df_prices=universe_data['price'】

# %%
df2
# Out:
#                    SPY         QQQ    simple_risk  linear_strategy  \
# Date
# 2023-01-31  388.669678  288.720367  104388.691130    102844.454128
# 2023-02-01  392.800323  294.894226  106176.371591    104558.636644
# 2023-02-02  398.518341  305.477936  105993.440784    104738.626254
# 2023-02-03  394.282410  300.048920  104387.955490    103061.812042
# 2023-02-06  391.872894  297.510712  103770.120029    102630.694687
# ...                ...         ...            ...              ...
# 2026-03-25  655.132202  587.174744  196179.167644    216329.033507
# 2026-03-26  643.432373  573.160095  191664.756284    208058.353826
# 2026-03-27  632.460632  561.962463  188228.776088    204069.086848
# 2026-03-30  630.346069  557.667175  185710.168598    198411.992469
# 2026-03-31  648.668884  576.546387  192289.546301    207030.649167
#
#             advanced_risk_strat  advanced_info_strat
# Date
# 2023-01-31        100000.000000        103310.418647
# 2023-02-01         99900.100000        104747.296353
# 2023-02-02         99336.132008        107891.365370
# 2023-02-03         98186.384609        105162.034288
# 2023-02-06         97989.503543        104517.888463
# ...                         ...                  ...
# 2026-03-25        185363.994073        216564.701148
# 2026-03-26        180323.139956        208526.742542
# 2026-03-27        176017.347062        205583.541778
# 2026-03-30        173370.327587        199478.170423
# 2026-03-31        180441.998270        208357.110153
#
# [794 rows x 6 columns]

# %%
metrics.calculate_metrics(df2)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.175828      1.377510       2.295791      0.187552
# QQQ                  0.244466      1.455031       2.455618      0.227683
# simple_risk          0.213103      1.331727       2.202346      0.149277
# linear_strategy      0.247639      1.278794       2.151712      0.239392
# advanced_risk_strat  0.205210      1.109247       1.854794      0.218266
# advanced_info_strat  0.248375      1.290166       2.154617      0.279106
#
#                      Calmar_Ratio
# SPY                      0.937488
# QQQ                      1.073711
# simple_risk              1.427569
# linear_strategy          1.034450
# advanced_risk_strat      0.940183
# advanced_info_strat      0.889895

# %%
# analysis.plot_rebased_performance(df_prices)

# %%
analysis.plot_rebased_performance(df2)#['2025-04-01':])

# %%
# Out:
# Timestamp('2026-03-31 00:00:00')

# %%
df_prices=universe_data['price']
today=df_prices.index[-1]
market_prices=df_prices.loc[today]
states['advanced_info_strat'].display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.0% Cash
#   - Core Liquid Cash : $101.62
#   - Total Core NAV   : $208,357.11
#           Shares      Price Market Value Sleeve Weight
# Ticker
# MNST    252.7165     $72.46   $18,311.84         8.79%
# ROST    100.6690    $216.21   $21,765.24        10.45%
# ADI      60.2174    $318.14   $19,157.57         9.19%
# AMAT     56.3628    $341.37   $19,240.33         9.23%
# LRCX     83.8142    $213.51   $17,895.13         8.59%
# KLAC    135.3506    $147.05   $19,903.76         9.55%
# AMGN     50.8637    $349.21   $17,762.25         8.52%
# MU       47.8429    $337.79   $16,160.75         7.76%
# ASML     14.1778  $1,317.95   $18,685.64         8.97%
# MRNA    402.9992     $50.80   $20,472.36         9.83%
# CSX     461.8406     $40.92   $18,900.62         9.07%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $208,357.11
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %% [markdown]
# ## 不同趋势

# %%
df3=df2.loc['2025-04-01':]

# %%
metrics.calculate_metrics(df3)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.173245      1.124137       1.887491      0.120527
# QQQ                  0.227800      1.225792       2.111931      0.126200
# simple_risk          0.093704      0.632164       1.050323      0.116194
# linear_strategy      0.286629      1.307568       2.213909      0.133763
# advanced_risk_strat  0.181800      0.968776       1.605386      0.142609
# advanced_info_strat  0.276534      1.337136       2.190219      0.133789
#
#                      Calmar_Ratio
# SPY                      1.437391
# QQQ                      1.805079
# simple_risk              0.806448
# linear_strategy          2.142803
# advanced_risk_strat      1.274816
# advanced_info_strat      2.066948

# %%
analysis.plot_rebased_performance(df3)

# %%
analysis.plot_rebased_performance(df2.loc['2025-04-01':,['QQQ','adv_line_nav']])

# %%
metrics.calculate_metrics(df2)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.175828      1.377511       2.295793      0.187552
# QQQ                  0.244466      1.455030       2.455618      0.227683
# simple_risk          0.106311      0.896535       1.453871      0.139828
# linear_strategy      0.065493      0.465521       0.767382      0.187872
# advanced_risk_strat  0.076956      0.600480       0.991062      0.202483
# advanced_info_strat  0.295452      1.387205       2.417199      0.249873
#
#                      Calmar_Ratio
# SPY                      0.937488
# QQQ                      1.073711
# simple_risk              0.760298
# linear_strategy          0.348606
# advanced_risk_strat      0.380062
# advanced_info_strat      1.182410

# %%
df2_vxx=df2

# %%
df_nav_effect=evaluate(g_state,effective_date='2023-01-01')
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $114.65
#   - Total Core NAV   : $158,961.07
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     163.2926  $318.14   $51,949.92        32.68%
# XEL     692.9367   $78.85   $54,634.84        34.37%
# DLTR    477.2319  $109.51   $52,261.66        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $158,961.07
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------
#
#                   CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# Core_NAV      0.153847      0.879248       1.446477      0.239168
# Tactical_NAV       NaN           NaN            NaN           NaN
# Total_NAV     0.153847      0.879248       1.446477      0.239168
#
#               Calmar_Ratio
# Core_NAV          0.643259
# Tactical_NAV           NaN
# Total_NAV         0.643259

# %%
# risk_adj_moment
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $103.16
#   - Total Core NAV   : $143,029.93
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     146.9278  $318.14   $46,743.62        32.68%
# XEL     623.4894   $78.85   $49,159.24        34.37%
# DLTR    429.4029  $109.51   $47,023.91        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $143,029.93
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# advanced_risk_strat
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $114.65
#   - Total Core NAV   : $158,961.07
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     163.2926  $318.14   $51,949.92        32.68%
# XEL     692.9367   $78.85   $54,634.84        34.37%
# DLTR    477.2319  $109.51   $52,261.66        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $158,961.07
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# for linear_strategy
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.0% Cash
#   - Core Liquid Cash : $0.07
#   - Total Core NAV   : $91,593.24
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI      97.6386  $318.14   $31,062.73        33.91%
# ALGN      0.0000  $171.43        $0.00         0.00%
# PANW      0.0000  $160.32        $0.00         0.00%
# CEG     104.9394  $278.82   $29,258.86        31.94%
# XEL       0.0000   $78.85        $0.00         0.00%
# DLTR    285.5592  $109.51   $31,271.58        34.14%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $91,593.24
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# for advanced info strategy
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.0% Cash
#   - Core Liquid Cash : $0.10
#   - Total Core NAV   : $129,977.29
#            Shares    Price Market Value Sleeve Weight
# Ticker
# ENPH    1092.8974   $37.81   $41,322.45        31.79%
# ALGN     258.5094  $171.43   $44,316.26        34.10%
# ADI      139.3678  $318.14   $44,338.48        34.11%
# INSM       0.0000  $163.52        $0.00         0.00%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $129,977.29
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %% [markdown]
# ## daily level

# %%
from src import analysis

# %%
reload(analysis)
# Out:
# <module 'src.analysis' from '/Users/zhigangyu/Documents/Project Z/src/analysis.py'>

# %%
metric_keys=audit_ledger[0].telemetry.metrics.keys()
df_ledger=audit.analyze_audit_trail(audit_ledger,metric_keys)
df_ledger.shape
# Out:
# (1131, 9)

# %%
df_nav=g_state.export_nav_dataframe()[['Total_NAV']]
df_nav=df_nav.rename({'Total_NAV':'nav'},axis=1)

# %%
df_trade=analysis.parse_backtest_log('backtest.log')
df_trade['shares2']=np.where(df_trade['type']=='CORE_SELL',-1*df_trade['shares'],df_trade['shares'])

# %%
df_ledger['trade_date']=df_ledger['date']+ pd.Timedelta(days=1)

# %%
df_trade2=df_trade.merge(df_ledger[['trade_date','ticker','final_weight']],left_on=['date','ticker'],right_on=['trade_date','ticker'])

# %%
df_trade2
# Out:
#          date       type ticker   shares   price    fee  shares2 trade_date  \
# 0  2023-02-01   CORE_BUY   SNPS    90.63  367.05  33.30    90.63 2023-02-01
# 1  2023-02-01   CORE_BUY     ON   427.37   77.84  33.30   427.37 2023-02-01
# 2  2023-02-01   CORE_BUY   CDNS   176.12  188.89  33.30   176.12 2023-02-01
# 3  2023-03-01  CORE_SELL     ON   427.37   78.23  33.43  -427.37 2023-03-01
# 4  2023-03-01  CORE_SELL   CDNS     2.05  191.43   0.39    -2.05 2023-03-01
# ..        ...        ...    ...      ...     ...    ...      ...        ...
# 82 2025-10-01  CORE_SELL   INSM   373.10  147.28  54.95  -373.10 2025-10-01
# 83 2025-10-01  CORE_SELL   FAST  1116.95   46.96  52.45 -1116.95 2025-10-01
# 84 2025-10-01   CORE_BUY    XEL   685.36   78.52  53.87   685.36 2025-10-01
# 85 2025-10-01   CORE_BUY  GOOGL   220.16  244.42  53.87   220.16 2025-10-01
# 86 2025-10-01   CORE_BUY     ZS   176.71  304.53  53.87   176.71 2025-10-01
#
#     final_weight
# 0       0.333333
# 1       0.333333
# 2       0.333333
# 3       0.000000
# 4       0.333333
# ..           ...
# 82      0.000000
# 83      0.000000
# 84      0.333333
# 85      0.333333
# 86      0.333333
#
# [87 rows x 9 columns]

# %%
df_trade3=analysis.generate_balance_df(df_trade,daily_resolution=False)
df_trade3=analysis.unpivot_balance_df(df_trade3)
df_trade3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df_trade3=analysis.generate_balance_df(df_trade,daily_resolution=False)
#       2 df_trade3=analysis.unpivot_balance_df(df_trade3)
#       3 df_trade3.head()
#
# NameError: name 'df_trade' is not defined

# %%
df_trade3.head(10)
# Out:
#          date ticker  shares
# 6  2023-02-01   CDNS  176.12
# 17 2023-02-01     ON  427.37
# 20 2023-02-01   SNPS   90.63
# 28 2023-03-01    ADI  190.84
# 31 2023-03-01   CDNS  174.07
# 45 2023-03-01   SNPS   92.29
# 53 2023-04-03    ADI  193.52
# 56 2023-04-03   CDNS  170.84
# 65 2023-04-03   MDLZ  562.23
# 70 2023-04-03   SNPS   -0.01

# %%
reload(analysis)
# Out:
# <module 'src.analysis' from '/Users/zhigangyu/Documents/Project Z/src/analysis.py'>

# %%
df_prices=universe_data['price']
df_prices.index.name='date'

# %%
df_enhanced_ledger=analysis.build_enhanced_ledger_from_balances(df_trade3,df_prices)

# %%
# chech the nav by g_state record and our log history, mainly match
df1=df_enhanced_ledger.loc[df_enhanced_ledger['is_rebalance_day']]
df2=df1.groupby('date')[['current_value']].sum()
df_nav_match=df_nav.merge(df2, right_index=True,left_index=True)

# %%
df_nav_diff=df_nav_match.diff()
df_nav_diff.sort_values('nav').head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_nav_diff=df_nav_match.diff()
#       2 df_nav_diff.sort_values('nav').head()
#
# NameError: name 'df_nav_match' is not defined

# %%
idx=df_enhanced_ledger['cum_pnl'].idxmin()
print(df_enhanced_ledger.loc[idx])
lost_ticker=df_enhanced_ledger.loc[idx]['ticker']
df1=df_trade3.loc[df_trade3['ticker']==lost_ticker]
# Out:
# date                2026-02-05 00:00:00
# ticker                              AMD
# shares_holding                   248.09
# current_price                     192.5
# current_value                 47757.325
# yesterday_value            49665.137706
# return_change                 -0.038414
# pnl_dollar                 -1907.812706
# entry_price                  246.274345
# cum_pnl                    -13340.87726
# weight                         0.282397
# shares_change                       0.0
# is_rebalance_day                  False
# Name: 29760, dtype: object

# %%
first_date=df1.iloc[0]['date']+pd.Timedelta(days=-10)
last_date=df1.iloc[-1]['date']+pd.Timedelta(days=+10)

# %%
df2=df_enhanced_ledger.loc[(df_enhanced_ledger['date']>=first_date)&(df_enhanced_ledger['date']<=last_date)]

# %%
analysis.plot_ticker_attribution(df2,ticker_symbol=lost_ticker)

# %% [markdown]
# ## evaluation

# %%
from src import metrics

# %%
print('info_moment')
# Out:
# info_moment

# %% [markdown]
# # evaluateion on bootstrap results

# %%
from src import stat_test

# %%
def nav_all(nav_list,col='Total_NAV'):
    nav_all=pd.concat([nav[col] for nav in nav_list],axis=1)
    nav_all.columns=range(0,len(nav_list))
    return nav_all

# %%
risk_nav_all=nav_all(risk_navs)
risk_nav_metrics=metrics.calculate_metrics(risk_nav_all)

# %%
info_nav_all=nav_all(info_navs)
info_nav_metrics=metrics.calculate_metrics(info_nav_all)

# %%
risk_nav_metrics.columns
# Out:
# Index(['CAGR', 'Sharpe_Ratio', 'Sortino_Ratio', 'Max_Drawdown',
#        'Calmar_Ratio'],
#       dtype='str')

# %%
for column in risk_nav_metrics.columns:
    print(f'----{column}----')
    s1,s2=risk_nav_metrics[column],info_nav_metrics[column]
    # test_res=stat_test.test_paired_series_non_parametric(s1,s2)
    test_res=stat_test.automated_paired_test(s1,s2)
    if not test_res['significant_at_5pct']:
        print(f'different: {s1.mean()} ..vs.. {s2.mean()}')
    else:
        print(f'same: {s1.mean()} ..vs.. {s2.mean()}')
# Out:
# ----CAGR----
# same: 0.1799114853780623 ..vs.. 0.1924236832228953
# ----Sharpe_Ratio----
# same: 0.7392562372772251 ..vs.. 0.6993231332027183
# ----Sortino_Ratio----
# same: 1.876469755704342 ..vs.. 1.8034742959731789
# ----Max_Drawdown----
# same: 0.2614017594246385 ..vs.. 0.29531564838493124
# ----Calmar_Ratio----
# same: 0.9910205376658745 ..vs.. 0.9232063324783212

# %%
(info_nav_metrics[['CAGR']]-risk_nav_metrics[['CAGR']]).hist()
# Out:
# array([[<Axes: title={'center': 'CAGR'}>]], dtype=object)

# %% [markdown]
# # benchmark

# %%
engine_bench,prices_3d,volume_3d=run2.get_bootstrap_words(bench_universe_data,NUM_SIMULATIONS)

# %%
# Run the Macro Orchestrator validation pass
spy_navs=[]
qqq_navs=[]

for sim_id in tqdm(range(NUM_SIMULATIONS)):
    # Pack the 3D slices into clean 2D DataFrames with the ORIGINAL calendar dates index
    # world_data_dict = {
    #     'price': pd.DataFrame(prices_3d[sim_id, :, :], index=engine.dates_index, columns=engine.tickers),
    #     'volume': pd.DataFrame(volume_3d[sim_id, :, :], index=engine.dates_index, columns=engine.tickers)
    # }
    df_prices=pd.DataFrame(prices_3d[sim_id, :, :], index=engine_bench.dates_index, columns=engine_bench.tickers)
    spy_navs.append(df_prices[['SPY']])
    qqq_navs.append(df_prices[['QQQ']])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1313.10it/s]

# %%
assert len(spy_navs)==len(qqq_navs)==NUM_SIMULATIONS

# %%
spy_nav_all=nav_all(spy_navs,'SPY')
qqq_nav_all=nav_all(qqq_navs,'QQQ')

# %%
sqy_nav_metrics=metrics.calculate_metrics(spy_nav_all)
qqq_nav_metrics=metrics.calculate_metrics(qqq_nav_all)

# %%
for column in sqy_nav_metrics.columns:
    print(f'----{column}----')
    s1,s2=sqy_nav_metrics[column],qqq_nav_metrics[column]
    test_res=stat_test.test_paired_series_non_parametric(s1,s2)
    if not test_res['significant_at_5pct']:
        print(f'different: {s1.mean()} ..vs.. {s2.mean()}')
    else:
        print(f'same: {s1.mean()} ..vs.. {s2.mean()}')
# Out:
# ----CAGR----
# same: 0.09446482332172962 ..vs.. 0.10137824440424797
# ----Sharpe_Ratio----
# same: 0.7289833702412534 ..vs.. 0.6374972764882084
# ----Sortino_Ratio----
# same: 1.220004877043697 ..vs.. 1.0713361812131421
# ----Max_Drawdown----
# same: 0.25675941436112626 ..vs.. 0.34280337500446895
# ----Calmar_Ratio----
# same: 0.46998721726869935 ..vs.. 0.39476742605700077
