# %%
import sys
from pathlib import Path
project_root = Path().resolve().parent  
project_root
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
import numpy as np
np.random.seed(42)

# %%
from importlib import reload

# %%
import pandas as pd
from tqdm import tqdm

# %%
from src import data_broker
from src import statioinary_bootstrap
from src import global_state

from src import calendar_iterator
from src import strategy_selector, ad_hoc_strategy

from src import executor_module, performance_evaluator
from src import compliance_filters, budget_allocator
from src import audit

from src import signal_schema
from src import metrics

from src import logging

# %%
reload(strategy_selector)
# Out:
# <module 'src.strategy_selector' from '/Users/zhigangyu/Documents/Project Z/src/strategy_selector.py'>

# %%
logger=logging.setup_logger(name="backtest_logger", log_file="backtest.log")

# %%
import ticker_loader
totak_tickers=ticker_loader.load_total_tickers()
# tickers=run2.get_random_sample(totak_tickers,30)

# %%
# 动量亏本 组合
# ','.join(tickers)
# tickers='ALGN,AAPL,PANW,AMD,ZS,MDLZ,XEL,VRSN,INSM,ON,WDAY,ENPH,DLTR,ADI,COST,ABNB,CEG,MSFT,GOOGL,CDNS,PYPL,FAST,JD,MTCH,SNPS,LULU,CMCSA,ADBE,ADSK'.split(',')

# %%
# tickers=['SPY','QQQ','QQQE','IWM','XSW','XLY','XLV','XLU','XLRE','XLP','XLK','XLI','XLF','XLE','XLC','XLB','LABU','XBI']#,'VXX']

# %%
tickers=totak_tickers

# %%
broker = data_broker.DataBroker(tickers=tickers, start_date="2022-01-01", end_date="2026-04-01")
universe_data = broker.fetch_universe_data()
# Out:
# [******************    38%                       ]  43 of 112 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: WBA"}}}
# [**********************46%                       ]  51 of 112 completed$XLNX: possibly delisted; no timezone found
# [**********************54%*                      ]  60 of 112 completed$SGEN: possibly delisted; no timezone found
# [**********************62%*****                  ]  69 of 112 completed$WBA: possibly delisted; no timezone found
# [**********************76%***********            ]  85 of 112 completed$ATVI: possibly delisted; no timezone found
# [**********************78%************           ]  87 of 112 completed$ANSS: possibly delisted; no timezone found
# [**********************91%*******************    ]  102 of 112 completed$FI: possibly delisted; no timezone found
# [**********************97%********************** ]  109 of 112 completed$SPLK: possibly delisted; no timezone found
# [*********************100%***********************]  112 of 112 completed
#
# 7 Failed downloads:
# ['XLNX', 'SGEN', 'WBA', 'ATVI', 'ANSS', 'FI', 'SPLK']: possibly delisted; no timezone found

# %%
universe_data=ticker_loader.fix_data(universe_data)
# Out:
# price shape before drop: (1064, 112)
# price shape after drop: (1064, 105)
# volume shape after drop: (1064, 105)

# %%
bench_tickers=['SPY','QQQ']
bench_broker = data_broker.DataBroker(tickers=bench_tickers, start_date="2022-01-01", end_date="2026-04-01")
bench_universe_data = bench_broker.fetch_universe_data()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# adhoc_exit=ad_hoc_strategy.AdHocChandelierExit()

# %%
reload(strategy_selector)
# Out:
# <module 'src.strategy_selector' from '/Users/zhigangyu/Documents/Project Z/src/strategy_selector.py'>

# %%
risk_adj_moment=strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.SimpleRiskAdjustedScorer(),
    long_window=126,
    short_window=10,
    structural_weight=.6
)

linear_strategy = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.TraditionalLinearRegressionScorer(),
    long_window=126,
    short_window=10,
    structural_weight=.6
)

# Configuration A: Advanced Risk-Adjusted Blended Momentum
advanced_risk_strat = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.GeometricDriftScorer(),
    long_window=252,
    short_window=10,
    structural_weight=.6
)

# Configuration B: Advanced Information Discrete Momentum (Time-Weighted)
advanced_info_strat = strategy_selector.ComprehensiveMultiHorizonStrategy(
    scorer=strategy_selector.WeightedLinearRegressionScorer(decay_factor=0.97),
    long_window=126,
    short_window=10,
    structural_weight=.6
)

# %%
#126, 10

# %%
strategies={'simple_risk':risk_adj_moment,
            'linear_strategy':linear_strategy,
            'advanced_risk_strat':advanced_risk_strat,
            'advanced_info_strat':advanced_info_strat,}

# %%
portfolio_filter=compliance_filters.LiquidityComplianceFilter()

# %% [markdown]
# # run only on the real data

# %%
def run(module_c_regular,module_c1_adhoc=None,is_filter=False,allocation_type='equal'):
    allocator=budget_allocator.IntegratedBudgetAllocator(top_percent=.10, allocation_type=allocation_type)
    g_state=global_state.GlobalState(initial_capital=100_000,core_allocation_pct=1.0)
    executor=executor_module.TransactionExecutor(trade_delay=1)
    calendar = calendar_iterator.CalendarIterator(world_data_dict, interval="ME")
    rebalance_dates = calendar.generate_rebalance_dates()
    
    
    
    # Initialize a formal ledger
    audit_ledger: list[audit.AuditRecord] = []
    logger.info("Initializing Backtest Engine...")
    
    for i, today in enumerate(world_data_dict['price'].index):
        snapshot = calendar.get_historical_snapshot(today)
        market_prices = snapshot['price'].loc[today]
        
        # Initialize containers for this specific time-step's audit trail
        current_telemetry = signal_schema.StrategyTelemetry()
        g_state.signals.clear_signals()
        
        # 1. Strategy Calculation Pass
        regular_strategy_output,adhoc_strategy_output=None, None
        raw_regular_signals,filtered_regular_signals=[],[]
        if today in rebalance_dates and (module_c_regular is not None):
            # Update your strategy to return the StrategyTelemetry object instead of loose info dicts
            regular_strategy_output, current_telemetry = module_c_regular.calculate_signals(snapshot)
            raw_regular_signals = list(regular_strategy_output.signals)
            if is_filter:
                regular_strategy_output = portfolio_filter.filter_signals(today, regular_strategy_output, snapshot)
                filtered_regular_signals=list(regular_strategy_output.signals)
            else:
                filtered_regular_signals=raw_regular_signals
    
            if regular_strategy_output.signals:
                logger.info(f"=== REBALANCE EVENT TRIGGERED: {today.strftime('%Y-%m-%d')} ===")
    
        raw_adhoc_signals,filtered_adhoc_signals=[],[]
        if module_c1_adhoc is not None:
            adhoc_strategy_output = module_c1_adhoc.evaluate_exits(g_state, snapshot)
            raw_adhoc_signals= list(adhoc_strategy_output.signals)
            adhoc_strategy_output = portfolio_filter.filter_signals(today, adhoc_strategy_output, snapshot)
            filtered_adhoc_signals=list(adhoc_strategy_output.signals)
        g_state.signals.update_signals(regular_strategy_output,adhoc_strategy_output)
        
    
        # 2. Allocation Pass
        core_target_weights, sell_adhoc_orders, buy_adhoc_orders = allocator.allocate_capital(
             g_state, market_prices,
        ) 
        
        
        g_state.need_trade.set_core(core_target_weights, today)
        g_state.need_trade.set_sell_adhoc(sell_adhoc_orders, today)
        g_state.need_trade.set_buy_adhoc(buy_adhoc_orders, today)
        
        # 3. Execution & Portfolio State Capture
        # (Capture the current trades before or during execution context if needed)
        executor.execute_trades(g_state, today, market_prices)
        g_state.record_daily_snapshot(today, market_prices)
        
        # 4. Commit to Audit Ledger only on actionable days to save memory, 
        # or every day depending on your debugging requirements
        if today in rebalance_dates and len(getattr(current_telemetry,'metrics',{}))!=0:
            
            audit_ledger.append(audit.AuditRecord(
                date=today,
                telemetry=current_telemetry,
                raw_regular_signals=raw_regular_signals,
                filtered_regular_signals=filtered_regular_signals,
                raw_adhoc_signals=raw_adhoc_signals,
                filtered_adhoc_signals=filtered_adhoc_signals,
                target_weights=core_target_weights,
                executed_trades=[] # Populate from executor if your executor keeps track
            ))
    
    logger.info("Backtest execution completed successfully.")
    return g_state

# %%
world_data_dict= universe_data

# %%
reload(executor_module)
# Out:
# <module 'src.executor_module' from '/Users/zhigangyu/Documents/Project Z/src/executor_module.py'>

# %%
states={}
for strat_name in strategies:
    print(f'******* {strat_name} *******')
    strategy=strategies[strat_name]
    state=run(strategy)#,allocation_type='score_weighted')
    states[strat_name]=state
# Out:
# ******* simple_risk *******
# [2026-07-06 23:41:53] INFO [backtest_logger]: Initializing Backtest Engine...
# [2026-07-06 23:41:53] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-07-29 ===
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ENPH ... 32.3@280.89, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ADP ... 41.18@220.32, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY SMCI ... 1642.42@5.52, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY SNPS ... 24.52@370.01, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY AEP ... 105.98@85.61, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY ON ... 142.52@63.66, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY MNST ... 184.24@49.24, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY PAYX ... 81.38@111.49, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY TRI ... 88.2@102.87, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY CTAS ... 88.81@102.16, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-08-01 00:00:00:CORE_BUY CDNS ... 49.03@185.04, fee: 9.08
# [2026-07-06 23:41:53] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-08-31 ===
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL ENPH ... 0.23@281.86, fee: 0.07
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL ADP ... 41.18@224.56, fee: 9.25
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL SMCI ... 214.71@6.33, fee: 1.36
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL SNPS ... 24.52@332.49, fee: 8.15
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL AEP ... 105.98@89.13, fee: 9.45
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL ON ... 10.03@68.22, fee: 0.68
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL PAYX ... 81.38@110.1, fee: 8.96
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL TRI ... 88.2@102.22, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL CTAS ... 88.81@98.47, fee: 8.75
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_SELL CDNS ... 49.03@170.04, fee: 8.34
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY GILD ... 159.17@56.62, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY PDD ... 126.18@71.42, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY MNST ... 18.83@44.5, fee: 0.84
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY NTES ... 112.04@80.43, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY VRTX ... 31.05@290.2, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY INSM ... 357.76@25.19, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY TMUS ... 65.48@137.63, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-09-01 00:00:00:CORE_BUY CEG ... 112.43@80.16, fee: 9.02
# [2026-07-06 23:41:53] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-09-30 ===
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL ENPH ... 2.0@286.61, fee: 0.57
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL GILD ... 159.17@54.94, fee: 8.75
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL ON ... 132.48@64.79, fee: 8.58
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL MNST ... 9.52@44.53, fee: 0.42
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL NTES ... 112.04@69.78, fee: 7.82
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL VRTX ... 2.08@297.43, fee: 0.62
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL INSM ... 357.76@22.16, fee: 7.93
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL TMUS ... 65.48@132.83, fee: 8.7
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_SELL CEG ... 112.43@84.11, fee: 9.46
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY TTD ... 140.59@61.13, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY ORLY ... 179.5@47.88, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY SMCI ... 82.44@5.71, fee: 0.47
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY PDD ... 11.37@62.65, fee: 0.71
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY BIIB ... 32.52@264.3, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY REGN ... 11.79@729.11, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY CSGP ... 119.38@71.99, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-10-03 00:00:00:CORE_BUY CDNS ... 50.47@170.28, fee: 8.6
# [2026-07-06 23:41:53] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-10-31 ===
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL TTD ... 140.59@53.08, fee: 7.46
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL ENPH ... 2.72@299.48, fee: 0.82
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL ORLY ... 32.2@55.6, fee: 1.79
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL SMCI ... 370.55@7.19, fee: 2.66
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL PDD ... 137.55@53.89, fee: 7.41
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL MNST ... 193.54@47.17, fee: 9.13
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL BIIB ... 32.52@280.04, fee: 9.11
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL REGN ... 11.79@753.68, fee: 8.88
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL CSGP ... 18.5@81.19, fee: 1.5
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL VRTX ... 28.98@314.2, fee: 9.11
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_SELL CDNS ... 50.47@150.93, fee: 7.62
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY TMUS ... 56.09@145.62, fee: 8.18
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY HON ... 44.07@185.34, fee: 8.18
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY GILD ... 116.78@69.95, fee: 8.18
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY AMGN ... 33.76@241.98, fee: 8.18
# [2026-07-06 23:41:53] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY NFLX ... 284.85@28.67, fee: 8.18
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY ISRG ... 33.09@246.86, fee: 8.18
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY PCAR ... 146.62@55.71, fee: 8.18
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-11-01 00:00:00:CORE_BUY CEG ... 88.03@92.79, fee: 8.18
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-11-30 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL ENPH ... 27.35@314.0, fee: 8.59
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL SMCI ... 79.67@9.05, fee: 0.72
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL HON ... 44.07@199.36, fee: 8.79
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL PCAR ... 146.62@61.1, fee: 8.96
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL AMGN ... 33.76@256.08, fee: 8.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL NFLX ... 284.85@31.69, fee: 9.03
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL CSGP ... 100.88@82.95, fee: 8.37
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL ISRG ... 33.09@274.49, fee: 9.08
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_SELL TMUS ... 56.09@145.17, fee: 8.14
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY ORLY ... 20.53@57.15, fee: 1.17
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY PEP ... 57.92@165.15, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY GILD ... 7.01@77.49, fee: 0.54
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY PDD ... 114.23@83.74, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY TRI ... 87.68@109.09, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY KHC ... 291.18@32.85, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY SBUX ... 100.75@94.95, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY ROST ... 84.33@113.43, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY KDP ... 274.41@34.86, fee: 9.58
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2022-12-01 00:00:00:CORE_BUY CEG ... 16.31@91.91, fee: 1.5
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2022-12-30 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL ORLY ... 2.75@56.05, fee: 0.15
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL PEP ... 57.92@159.38, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL GILD ... 123.78@75.91, fee: 9.4
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL PDD ... 114.23@84.53, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL TRI ... 87.68@107.29, fee: 9.41
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL KHC ... 18.45@33.92, fee: 0.63
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL SBUX ... 0.84@92.61, fee: 0.08
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL ROST ... 1.46@111.65, fee: 0.16
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL KDP ... 274.41@32.01, fee: 8.78
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_SELL CEG ... 104.34@79.69, fee: 8.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY SMCI ... 43.29@8.39, fee: 0.36
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY HON ... 46.94@196.52, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY VRSN ... 46.38@198.9, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY AVGO ... 174.97@52.72, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY NFLX ... 312.77@29.5, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY CTAS ... 84.81@108.77, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-01-03 00:00:00:CORE_BUY PCAR ... 158.08@58.36, fee: 9.23
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-01-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL ORLY ... 165.08@53.86, fee: 8.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL SMCI ... 1103.22@7.97, fee: 8.8
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL HON ... 46.94@189.57, fee: 8.9
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL VRSN ... 1.87@217.43, fee: 0.41
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL AVGO ... 174.97@57.42, fee: 10.05
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL KHC ... 272.73@33.72, fee: 9.2
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL NFLX ... 312.77@36.2, fee: 11.32
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL SBUX ... 4.11@101.03, fee: 0.42
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL ROST ... 82.87@114.25, fee: 9.47
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL CTAS ... 84.81@108.13, fee: 9.17
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_SELL PCAR ... 11.5@66.02, fee: 0.76
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY BKNG ... 100.73@95.79, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY MAR ... 56.93@169.5, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY WDAY ... 52.07@185.33, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY PDD ... 93.7@102.98, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY CSCO ... 218.3@44.2, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY REGN ... 12.84@751.79, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY MELI ... 7.95@1214.29, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-02-01 00:00:00:CORE_BUY VRTX ... 30.41@317.27, fee: 9.66
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-02-28 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL BKNG ... 7.42@99.97, fee: 0.74
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL MAR ... 56.93@164.16, fee: 9.35
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL WDAY ... 52.07@184.12, fee: 9.59
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL PDD ... 93.7@91.04, fee: 8.53
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL CSCO ... 6.26@43.99, fee: 0.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL VRSN ... 44.51@193.34, fee: 8.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL REGN ... 0.63@764.13, fee: 0.48
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL MELI ... 0.23@1208.72, fee: 0.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL SBUX ... 95.79@93.63, fee: 8.97
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL VRTX ... 30.41@291.23, fee: 8.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_SELL PCAR ... 3.48@65.19, fee: 0.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY SMCI ... 911.87@10.2, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY ADI ... 53.43@174.09, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY NVDA ... 410.21@22.67, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY AMAT ... 81.5@114.12, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY AVGO ... 164.49@56.54, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-03-01 00:00:00:CORE_BUY CPRT ... 266.51@34.9, fee: 9.31
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-03-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL SMCI ... 911.87@11.27, fee: 10.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL NVDA ... 49.2@27.94, fee: 1.37
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL AMAT ... 81.5@119.05, fee: 9.7
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL CSCO ... 212.04@47.61, fee: 10.09
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL AVGO ... 164.49@61.64, fee: 10.14
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL REGN ... 12.21@819.42, fee: 10.0
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_SELL MELI ... 0.04@1313.64, fee: 0.05
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY ORLY ... 173.83@57.86, fee: 10.07
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY BKNG ... 3.32@104.39, fee: 0.35
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY ADI ... 0.63@186.61, fee: 0.12
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY MDLZ ... 157.06@64.04, fee: 10.07
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY GILD ... 134.65@74.7, fee: 10.07
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY AZN ... 76.34@131.76, fee: 10.07
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY CPRT ... 0.8@37.74, fee: 0.03
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY TRI ... 82.18@122.39, fee: 10.07
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-04-03 00:00:00:CORE_BUY PCAR ... 11.64@65.18, fee: 0.76
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-04-28 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL ORLY ... 173.83@61.97, fee: 10.77
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL ADI ... 54.06@173.55, fee: 9.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL MDLZ ... 10.99@70.43, fee: 0.77
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL GILD ... 134.65@73.07, fee: 9.84
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL NVDA ... 4.85@28.88, fee: 0.14
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL AZN ... 76.34@138.52, fee: 10.57
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL PCAR ... 154.74@66.74, fee: 10.33
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL CPRT ... 4.87@39.2, fee: 0.19
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_SELL MELI ... 7.68@1291.65, fee: 9.92
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY BKNG ... 0.97@105.4, fee: 0.1
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY MSFT ... 34.44@297.85, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY MNST ... 180.45@56.84, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY TRI ... 1.14@123.47, fee: 0.14
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY CMCSA ... 295.45@34.72, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY META ... 42.55@241.06, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY SBUX ... 96.99@105.75, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-05-01 00:00:00:CORE_BUY ISRG ... 33.85@303.02, fee: 10.27
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-05-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL BKNG ... 97.6@99.88, fee: 9.75
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MSFT ... 34.44@324.89, fee: 11.19
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MDLZ ... 146.07@67.13, fee: 9.81
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL NVDA ... 87.94@39.73, fee: 3.49
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL MNST ... 180.45@59.36, fee: 10.71
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL CPRT ... 19.57@43.9, fee: 0.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL TRI ... 83.32@116.24, fee: 9.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL CMCSA ... 295.45@32.55, fee: 9.62
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL META ... 3.1@270.24, fee: 0.84
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL SBUX ... 96.99@90.47, fee: 8.77
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_SELL ISRG ... 33.85@310.54, fee: 10.51
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY SMCI ... 460.13@23.1, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY SNPS ... 23.39@454.55, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY TEAM ... 59.97@177.26, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY WDAY ... 49.37@215.31, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY AVGO ... 140.25@75.79, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY OKTA ... 142.32@74.69, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY NFLX ... 263.69@40.31, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-06-01 00:00:00:CORE_BUY CDNS ... 45.74@232.39, fee: 10.64
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-06-30 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL SMCI ... 20.67@24.92, fee: 0.51
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL SNPS ... 23.39@434.01, fee: 10.15
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL TEAM ... 59.97@167.59, fee: 10.05
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL WDAY ... 49.37@224.59, fee: 11.09
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL NVDA ... 268.22@42.38, fee: 11.37
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL AVGO ... 140.25@84.54, fee: 11.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL OKTA ... 142.32@69.26, fee: 9.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL META ... 0.82@283.53, fee: 0.23
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL NFLX ... 263.69@44.14, fee: 11.64
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_SELL CDNS ... 45.74@235.4, fee: 10.77
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY PANW ... 85.76@127.32, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY AMZN ... 83.85@130.22, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY MDB ... 26.54@411.42, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY FAST ... 401.96@27.16, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY FTNT ... 146.24@74.66, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY ALGN ... 31.69@344.59, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY AAPL ... 57.53@189.8, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-07-03 00:00:00:CORE_BUY PCAR ... 145.78@74.89, fee: 10.93
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-07-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL SMCI ... 95.04@33.76, fee: 3.21
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL PANW ... 85.76@126.58, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL AMZN ... 83.85@131.69, fee: 11.04
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL MDB ... 26.54@424.57, fee: 11.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL PCAR ... 145.78@77.39, fee: 11.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL CPRT ... 242.86@44.42, fee: 10.79
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL FTNT ... 146.24@78.03, fee: 11.41
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL META ... 2.27@319.9, fee: 0.73
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_SELL ALGN ... 31.69@376.62, fee: 11.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY LRCX ... 166.38@69.69, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY GOOGL ... 88.93@130.39, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY WDAY ... 48.35@239.8, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY AMAT ... 77.86@148.93, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY CRWD ... 279.48@41.49, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY FAST ... 24.07@27.29, fee: 0.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY ADBE ... 21.12@549.1, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY GOOG ... 88.69@130.74, fee: 11.61
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-08-01 00:00:00:CORE_BUY AAPL ... 2.75@192.91, fee: 0.53
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-08-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL LRCX ... 166.38@68.33, fee: 11.37
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL GOOGL ... 4.13@134.47, fee: 0.56
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL WDAY ... 48.35@248.49, fee: 12.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL AMAT ... 77.86@150.58, fee: 11.72
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL CRWD ... 279.48@40.31, fee: 11.26
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL ADBE ... 0.87@563.21, fee: 0.49
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL FAST ... 426.03@26.8, fee: 11.42
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL META ... 36.35@293.8, fee: 10.68
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_SELL GOOG ... 4.61@135.6, fee: 0.63
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY SMCI ... 59.51@28.22, fee: 1.68
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY INTU ... 21.09@539.14, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY NVDA ... 234.55@48.47, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY CSCO ... 212.75@53.44, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY AVGO ... 135.08@84.16, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY VRSK ... 47.8@237.85, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY ISRG ... 36.62@310.41, fee: 11.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-09-01 00:00:00:CORE_BUY AAPL ... 0.66@187.09, fee: 0.12
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-09-29 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL SMCI ... 26.28@28.89, fee: 0.76
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL INTU ... 21.09@507.95, fee: 10.71
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL GOOGL ... 84.79@132.99, fee: 11.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL CSCO ... 212.75@50.25, fee: 10.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL AVGO ... 0.35@80.98, fee: 0.03
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL ADBE ... 20.24@521.13, fee: 10.55
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL VRSK ... 47.8@231.82, fee: 11.08
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL GOOG ... 84.08@133.99, fee: 11.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL ISRG ... 36.62@294.98, fee: 10.8
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_SELL AAPL ... 60.94@171.58, fee: 10.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY SNPS ... 23.45@463.82, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY KLAC ... 241.56@45.03, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY NVDA ... 9.22@44.75, fee: 0.41
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY CRWD ... 256.63@42.38, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY AMGN ... 44.43@244.84, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY META ... 35.76@304.15, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY ZS ... 67.61@160.89, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY COST ... 19.78@549.92, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-10-02 00:00:00:CORE_BUY CEG ... 105.72@102.89, fee: 10.89
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-10-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL SMCI ... 377.66@25.23, fee: 9.53
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL SNPS ... 23.45@475.38, fee: 11.15
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL KLAC ... 241.56@46.58, fee: 11.25
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL CRWD ... 256.63@44.59, fee: 11.44
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL AVGO ... 134.73@82.72, fee: 11.14
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL AMGN ... 44.43@239.81, fee: 10.65
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL META ... 35.76@309.14, fee: 11.06
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL ZS ... 67.61@156.65, fee: 10.59
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL COST ... 19.78@535.95, fee: 10.6
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_SELL CEG ... 9.25@112.83, fee: 1.04
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY AMZN ... 79.22@137.0, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NVDA ... 13.57@42.3, fee: 0.57
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY PDD ... 105.44@102.93, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY MDB ... 32.01@339.02, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NTES ... 107.61@100.86, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY ADBE ... 19.93@544.5, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY NFLX ... 258.29@42.02, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY CTAS ... 87.34@124.27, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY INSM ... 434.3@24.99, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-11-01 00:00:00:CORE_BUY PCAR ... 145.3@74.69, fee: 10.86
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-11-30 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL AMZN ... 79.22@147.03, fee: 11.65
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NVDA ... 257.33@46.73, fee: 12.03
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL PDD ... 20.79@145.27, fee: 3.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL MDB ... 32.01@435.23, fee: 13.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL PCAR ... 145.3@83.96, fee: 12.2
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NTES ... 107.61@102.26, fee: 11.0
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL ADBE ... 19.93@612.47, fee: 12.21
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL NFLX ... 258.29@46.57, fee: 12.03
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL CTAS ... 87.34@136.64, fee: 11.93
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL INSM ... 434.3@26.52, fee: 11.52
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_SELL CEG ... 96.47@118.05, fee: 11.39
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY PANW ... 82.82@148.08, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY INTU ... 21.73@564.37, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY WDAY ... 44.94@272.92, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY CRWD ... 208.72@58.76, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY PAYX ... 107.64@113.94, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY ZS ... 61.93@198.03, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY COST ... 21.33@574.98, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY LULU ... 26.28@466.61, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY ROST ... 95.4@128.55, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2023-12-01 00:00:00:CORE_BUY TMUS ... 83.87@146.23, fee: 12.28
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2023-12-29 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PANW ... 82.82@144.46, fee: 11.96
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL INTU ... 0.3@593.3, fee: 0.18
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL WDAY ... 44.94@268.28, fee: 12.06
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PDD ... 84.65@145.64, fee: 12.33
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL CRWD ... 208.72@61.72, fee: 12.88
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL PAYX ... 107.64@108.38, fee: 11.66
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL ZS ... 61.93@212.37, fee: 13.15
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL COST ... 1.51@641.71, fee: 0.97
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL LULU ... 1.12@505.38, fee: 0.57
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL ROST ... 0.7@134.28, fee: 0.09
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_SELL TMUS ... 2.09@155.51, fee: 0.33
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY INTC ... 268.8@47.17, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY CDW ... 59.64@212.6, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY AMGN ... 46.01@275.56, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY META ... 36.94@343.28, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY CTAS ... 87.52@144.87, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-01-02 00:00:00:CORE_BUY INSM ... 423.48@29.94, fee: 12.69
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-01-31 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL TMUS ... 81.77@156.08, fee: 12.76
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INTU ... 0.54@622.84, fee: 0.34
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INTC ... 268.8@42.79, fee: 11.5
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL CDW ... 59.64@221.67, fee: 13.22
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL AMGN ... 2.74@300.74, fee: 0.83
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL META ... 36.94@391.34, fee: 14.45
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL COST ... 1.12@695.82, fee: 0.78
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL LULU ... 25.16@461.94, fee: 11.62
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL ROST ... 1.47@139.58, fee: 0.21
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL CTAS ... 1.43@151.15, fee: 0.22
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_SELL INSM ... 423.48@28.53, fee: 12.08
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY NVDA ... 205.98@62.99, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY CRWD ... 173.35@74.84, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY ZS ... 54.5@238.06, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY ASML ... 14.88@872.03, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY PCAR ... 136.53@95.03, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-02-01 00:00:00:CORE_BUY CEG ... 103.23@125.68, fee: 12.99
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-02-29 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL INTU ... 20.89@655.96, fee: 13.7
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL NVDA ... 205.98@82.23, fee: 16.94
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CRWD ... 173.35@78.65, fee: 13.63
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL AMGN ... 43.27@261.79, fee: 11.33
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL ZS ... 54.5@219.23, fee: 11.95
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL ASML ... 14.88@972.04, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CTAS ... 86.09@154.14, fee: 13.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL PCAR ... 3.64@105.7, fee: 0.38
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_SELL CEG ... 19.33@167.39, fee: 3.24
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY MAR ... 57.23@244.71, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY TMUS ... 88.9@157.54, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY AMZN ... 78.59@178.22, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY AMD ... 69.12@202.64, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY CSX ... 378.52@37.0, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY MU ... 148.39@94.38, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY FAST ... 403.66@34.7, fee: 14.02
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY COST ... 0.28@740.22, fee: 0.2
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-03-01 00:00:00:CORE_BUY ROST ... 3.02@145.94, fee: 0.44
# [2026-07-06 23:41:54] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-03-28 ===
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL MAR ... 57.23@246.01, fee: 14.08
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL TMUS ... 88.9@156.86, fee: 13.95
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL AMD ... 69.12@183.34, fee: 12.67
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL CSX ... 378.52@35.6, fee: 13.47
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL MU ... 31.03@123.42, fee: 3.83
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL FAST ... 6.53@36.48, fee: 0.24
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL COST ... 18.98@712.37, fee: 13.52
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL ROST ... 96.24@141.87, fee: 13.65
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL PCAR ... 6.86@114.96, fee: 0.79
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_SELL CEG ... 4.94@183.5, fee: 0.91
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY LRCX ... 149.96@96.33, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY AMZN ... 1.47@180.97, fee: 0.27
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CDW ... 59.11@244.42, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY AVGO ... 109.35@132.11, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CPRT ... 248.78@58.07, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY ASML ... 14.83@974.01, fee: 14.46
# [2026-07-06 23:41:54] INFO [backtest_logger]:     2024-04-01 00:00:00:CORE_BUY CTAS ... 86.54@166.94, fee: 14.46
# [2026-07-06 23:41:55] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-04-30 ===
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL LRCX ... 149.96@85.18, fee: 12.77
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL AMZN ... 80.06@179.0, fee: 14.33
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL PCAR ... 126.03@99.31, fee: 12.52
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL AVGO ... 109.35@121.61, fee: 13.3
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL MU ... 117.37@108.92, fee: 12.78
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CPRT ... 248.78@54.44, fee: 13.54
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL FAST ... 397.14@32.67, fee: 12.97
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL ASML ... 14.83@838.31, fee: 12.43
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CTAS ... 86.54@162.78, fee: 14.09
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_SELL CEG ... 78.95@182.1, fee: 14.38
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY KLAC ... 201.47@65.43, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY ADI ... 70.18@187.86, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY NVDA ... 158.85@82.99, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY AZN ... 89.57@147.18, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY CDW ... 4.67@207.28, fee: 0.97
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY QCOM ... 83.86@157.2, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY KHC ... 413.14@31.91, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY COST ... 18.45@714.48, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY EBAY ... 267.44@49.3, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY NXPI ... 55.0@239.72, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-05-01 00:00:00:CORE_BUY TMUS ... 82.62@159.56, fee: 13.2
# [2026-07-06 23:41:55] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2024-05-31 ===
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL KLAC ... 2.08@74.24, fee: 0.15
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL ADI ... 70.18@224.99, fee: 15.79
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL NVDA ... 30.08@114.94, fee: 3.46
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL AZN ... 89.57@152.15, fee: 13.63
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL CDW ... 63.78@216.43, fee: 13.8
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL QCOM ... 9.13@198.05, fee: 1.81
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL KHC ... 413.14@30.87, fee: 12.75
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL COST ... 0.1@806.66, fee: 0.08
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_SELL NXPI ... 55.0@259.43, fee: 14.27
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY AMAT ... 70.07@210.66, fee: 14.78
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY NFLX ... 232.89@63.38, fee: 14.78
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY ASML ... 15.55@949.03, fee: 14.78
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY EBAY ... 17.08@52.02, fee: 0.89
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY MRNA ... 99.85@147.82, fee: 14.78
# [2026-07-06 23:41:55] INFO [backtest_logger]:     2024-06-03 00:00:00:CORE_BUY TMUS ... 5.72@167.54, fee: 0.96
# ...
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL AMD ... 21.4@171.7, fee: 3.68
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL NTES ... 120.41@124.28, fee: 14.96
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL CRWD ... 128.78@111.67, fee: 14.38
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL AVGO ... 3.38@286.54, fee: 0.97
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL NFLX ... 122.47@115.86, fee: 14.19
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL ZS ... 51.55@280.27, fee: 14.45
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_SELL MELI ... 6.31@2375.92, fee: 15.0
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY SNPS ... 26.2@618.65, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY INTU ... 21.02@770.93, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY CDNS ... 45.4@356.97, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY INSM ... 149.11@108.69, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY DLTR ... 141.27@114.72, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-08-01 00:00:00:CORE_BUY CEG ... 47.81@338.99, fee: 16.22
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-08-29 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL SMCI ... 286.92@40.78, fee: 11.7
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL SNPS ... 26.2@592.01, fee: 15.51
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL INTU ... 21.02@657.54, fee: 13.82
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL MSFT ... 31.26@501.94, fee: 15.69
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL NVDA ... 93.57@170.75, fee: 15.98
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL AMD ... 94.64@162.32, fee: 15.36
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL AVGO ... 3.75@296.07, fee: 1.11
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL CDNS ... 45.4@342.81, fee: 15.56
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL INSM ... 41.2@145.3, fee: 5.99
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL DLTR ... 141.27@111.35, fee: 15.73
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_SELL CEG ... 47.81@305.95, fee: 14.63
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY LRCX ... 162.07@96.5, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY ADI ... 63.4@246.67, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY IDXX ... 24.46@639.45, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY GOOGL ... 74.21@210.75, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY DDOG ... 116.11@134.69, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY CSCO ... 235.45@66.42, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY NTES ... 117.56@133.04, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY GOOG ... 73.99@211.39, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-09-02 00:00:00:CORE_BUY MDB ... 49.14@318.29, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-09-30 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL LRCX ... 40.82@142.28, fee: 5.81
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL ADI ... 63.4@237.69, fee: 15.07
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL IDXX ... 24.46@620.11, fee: 15.17
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL GOOGL ... 74.21@244.42, fee: 18.14
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL DDOG ... 116.11@152.7, fee: 17.73
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL MDB ... 49.14@321.53, fee: 15.8
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL CSCO ... 235.45@67.36, fee: 15.86
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL NTES ... 117.56@147.07, fee: 17.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL AVGO ... 52.98@331.53, fee: 17.56
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL GOOG ... 73.99@245.06, fee: 18.13
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_SELL INSM ... 107.91@147.28, fee: 15.89
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY XEL ... 219.15@78.52, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY KLAC ... 153.08@112.41, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY TSLA ... 37.45@459.46, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY NVDA ... 91.91@187.22, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY INTC ... 478.77@35.94, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY EA ... 85.58@201.06, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY PTON ... 1984.68@8.67, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY FAST ... 366.41@46.96, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY ASML ... 17.24@997.99, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-10-01 00:00:00:CORE_BUY AAPL ... 67.55@254.73, fee: 17.22
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-10-31 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL XEL ... 219.15@79.45, fee: 17.41
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL LRCX ... 11.54@160.67, fee: 1.85
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL KLAC ... 7.86@121.4, fee: 0.95
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL TSLA ... 37.45@468.37, fee: 17.54
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL NVDA ... 6.69@206.86, fee: 1.38
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL INTC ... 32.48@39.5, fee: 1.28
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL EA ... 85.58@199.33, fee: 17.06
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL PTON ... 1984.68@7.27, fee: 14.43
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL FAST ... 366.41@40.6, fee: 14.88
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL ASML ... 17.24@1063.09, fee: 18.33
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_SELL AAPL ... 67.55@268.29, fee: 18.12
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY GOOGL ... 62.08@283.17, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY AMD ... 67.7@259.65, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY AVGO ... 48.76@360.53, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY MU ... 74.97@234.47, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY GOOG ... 61.99@283.56, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY INSM ... 94.39@186.23, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-11-03 00:00:00:CORE_BUY MDB ... 47.63@369.05, fee: 17.6
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-11-28 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL KLAC ... 145.22@115.42, fee: 16.76
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL GOOGL ... 6.19@314.28, fee: 1.95
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL NVDA ... 85.22@179.9, fee: 15.33
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL INTC ... 7.27@40.01, fee: 0.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL AMD ... 67.7@219.76, fee: 14.88
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL MDB ... 47.63@328.87, fee: 15.66
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL AVGO ... 3.01@383.93, fee: 1.15
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL MU ... 74.97@240.23, fee: 18.01
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL GOOG ... 6.14@314.5, fee: 1.93
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_SELL INSM ... 11.31@211.41, fee: 2.39
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY LRCX ... 4.16@154.24, fee: 0.64
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY IDXX ... 24.03@728.97, fee: 17.53
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY AMAT ... 68.92@254.12, fee: 17.53
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY BIIB ... 98.52@177.78, fee: 17.53
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY REGN ... 23.41@748.09, fee: 17.53
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2025-12-01 00:00:00:CORE_BUY ROST ... 99.3@176.38, fee: 17.53
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2025-12-31 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL LRCX ... 19.17@184.71, fee: 3.54
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL IDXX ... 24.03@669.99, fee: 16.1
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL GOOGL ... 0.3@314.74, fee: 0.09
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL AMAT ... 3.7@268.2, fee: 0.99
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL BIIB ... 0.13@177.82, fee: 0.02
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL AVGO ... 45.75@346.34, fee: 15.85
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL REGN ... 0.82@774.22, fee: 0.63
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL GOOG ... 0.29@314.91, fee: 0.09
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL ROST ... 99.3@182.0, fee: 18.07
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_SELL INSM ... 83.08@177.12, fee: 14.71
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY INTC ... 5.22@39.38, fee: 0.21
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY AZN ... 96.24@181.25, fee: 17.46
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY MNST ... 229.04@76.16, fee: 17.46
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY MU ... 55.34@315.24, fee: 17.46
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-01-02 00:00:00:CORE_BUY ASML ... 15.04@1159.71, fee: 17.46
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-01-30 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL LRCX ... 10.05@237.05, fee: 2.38
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL AMAT ... 3.97@327.58, fee: 1.3
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL INTC ... 444.25@48.81, fee: 21.68
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL AZN ... 96.24@186.47, fee: 17.95
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL MNST ... 229.04@81.1, fee: 18.58
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL MU ... 9.48@437.55, fee: 4.15
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL REGN ... 22.6@752.99, fee: 17.01
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_SELL ASML ... 1.07@1436.35, fee: 1.54
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY KLAC ... 142.24@140.68, fee: 20.03
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY ADI ... 63.35@315.87, fee: 20.03
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GOOGL ... 2.87@343.24, fee: 0.99
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GILD ... 141.77@141.16, fee: 20.03
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY BIIB ... 13.63@179.09, fee: 2.44
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY GOOG ... 2.7@344.45, fee: 0.93
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-02-02 00:00:00:CORE_BUY VRTX ... 42.4@472.01, fee: 20.03
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-02-27 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL KLAC ... 9.66@153.3, fee: 1.48
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL ADI ... 5.5@351.31, fee: 1.93
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GOOGL ... 58.46@306.12, fee: 17.9
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GILD ... 141.77@148.21, fee: 21.01
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL AMAT ... 6.58@371.72, fee: 2.45
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL BIIB ... 112.02@188.05, fee: 21.07
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL GOOG ... 58.26@305.96, fee: 17.82
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_SELL VRTX ... 42.4@486.03, fee: 20.61
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY LRCX ... 3.5@230.56, fee: 0.81
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY MNST ... 250.03@81.06, fee: 20.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY CSX ... 470.91@43.04, fee: 20.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY MU ... 3.42@412.43, fee: 1.41
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY AMGN ... 52.94@382.81, fee: 20.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY ASML ... 0.34@1420.44, fee: 0.48
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY ROST ... 100.59@201.48, fee: 20.29
# [2026-07-06 23:42:05] INFO [backtest_logger]:     2026-03-02 00:00:00:CORE_BUY MRNA ... 383.52@52.85, fee: 20.29
# [2026-07-06 23:42:05] INFO [backtest_logger]: === REBALANCE EVENT TRIGGERED: 2026-03-31 ===
# [2026-07-06 23:42:05] INFO [backtest_logger]: Backtest execution completed successfully.

# %% [markdown]
# # analysis

# %%
from src import analysis

# %%
def evaluate(g_state,effective_date='2023-01-01'):
    g_state.display_current_state(today,market_prices)
    df_nav=g_state.export_nav_dataframe()
    df_nav_effect=df_nav.loc[df_nav.index>='2023-01-01']
    print(metrics.calculate_metrics(df_nav_effect))
    return df_nav_effect

# %%
effective_date='2023-01-31'
bench_price=bench_universe_data['price']

# %%
df_nav_list=[]
for strat_name in states:
    print(strat_name)
    g_state=states[strat_name]
    df_nav=g_state.export_nav_dataframe()[['Total_NAV']]
    df_nav=df_nav.rename({'Total_NAV':strat_name},axis=1)
    df_nav_list.append(df_nav)
# Out:
# simple_risk
# linear_strategy
# advanced_risk_strat
# advanced_info_strat

# %%
df1=pd.concat([bench_price]+df_nav_list,axis=1)
df2=df1.loc[effective_date:]

# %%
# df_prices=universe_data['price'】

# %%
metrics.calculate_metrics(df2)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.175828      1.377511       2.295794      0.187552
# QQQ                  0.244466      1.455030       2.455618      0.227683
# simple_risk          0.212723      1.331052       2.201151      0.148967
# linear_strategy      0.246048      1.274427       2.143704      0.238115
# advanced_risk_strat  0.203861      1.107220       1.851649      0.218508
# advanced_info_strat  0.248261      1.294050       2.162892      0.279547
#
#                      Calmar_Ratio
# SPY                      0.937488
# QQQ                      1.073710
# simple_risk              1.427987
# linear_strategy          1.033318
# advanced_risk_strat      0.932968
# advanced_info_strat      0.888085

# %%
metrics.calculate_metrics(df2)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.175828      1.377511       2.295794      0.187552
# QQQ                  0.244466      1.455030       2.455618      0.227683
# simple_risk          0.240181      1.274107       2.188462      0.209195
# linear_strategy      0.153771      0.781633       1.252169      0.324883
# advanced_risk_strat  0.206398      1.005115       1.629795      0.264491
# advanced_info_strat  0.132262      0.709182       1.136810      0.329811
#
#                      Calmar_Ratio
# SPY                      0.937488
# QQQ                      1.073710
# simple_risk              1.148121
# linear_strategy          0.473311
# advanced_risk_strat      0.780358
# advanced_info_strat      0.401024

# %%
# analysis.plot_rebased_performance(df_prices)

# %%
analysis.plot_rebased_performance(df2)#['2025-04-01':])

# %% [markdown]
# ## 不同趋势

# %%
df3=df2.loc['2025-04-01':]

# %%
metrics.calculate_metrics(df3)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.173245      1.124137       1.887492      0.120527
# QQQ                  0.227800      1.225792       2.111929      0.126200
# simple_risk          0.081380      0.581347       0.951950      0.111693
# linear_strategy      0.043313      0.354572       0.560538      0.170578
# advanced_risk_strat  0.218013      1.151778       1.892588      0.127808
# advanced_info_strat  0.281606      1.371513       2.195485      0.125645
#
#                      Calmar_Ratio
# SPY                      1.437390
# QQQ                      1.805078
# simple_risk              0.728611
# linear_strategy          0.253920
# advanced_risk_strat      1.705788
# advanced_info_strat      2.241288

# %%
analysis.plot_rebased_performance(df3)

# %%
analysis.plot_rebased_performance(df2.loc['2025-04-01':,['QQQ','adv_line_nav']])

# %%
metrics.calculate_metrics(df2)
# Out:
#                          CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# SPY                  0.175828      1.377511       2.295793      0.187552
# QQQ                  0.244466      1.455030       2.455618      0.227683
# simple_risk          0.106311      0.896535       1.453871      0.139828
# linear_strategy      0.065493      0.465521       0.767382      0.187872
# advanced_risk_strat  0.076956      0.600480       0.991062      0.202483
# advanced_info_strat  0.295452      1.387205       2.417199      0.249873
#
#                      Calmar_Ratio
# SPY                      0.937488
# QQQ                      1.073711
# simple_risk              0.760298
# linear_strategy          0.348606
# advanced_risk_strat      0.380062
# advanced_info_strat      1.182410

# %%
df2_vxx=df2

# %%
df_nav_effect=evaluate(g_state,effective_date='2023-01-01')
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $114.65
#   - Total Core NAV   : $158,961.07
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     163.2926  $318.14   $51,949.92        32.68%
# XEL     692.9367   $78.85   $54,634.84        34.37%
# DLTR    477.2319  $109.51   $52,261.66        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $158,961.07
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------
#
#                   CAGR  Sharpe_Ratio  Sortino_Ratio  Max_Drawdown  \
# Core_NAV      0.153847      0.879248       1.446477      0.239168
# Tactical_NAV       NaN           NaN            NaN           NaN
# Total_NAV     0.153847      0.879248       1.446477      0.239168
#
#               Calmar_Ratio
# Core_NAV          0.643259
# Tactical_NAV           NaN
# Total_NAV         0.643259

# %%
# risk_adj_moment
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $103.16
#   - Total Core NAV   : $143,029.93
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     146.9278  $318.14   $46,743.62        32.68%
# XEL     623.4894   $78.85   $49,159.24        34.37%
# DLTR    429.4029  $109.51   $47,023.91        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $143,029.93
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# advanced_risk_strat
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.1% Cash
#   - Core Liquid Cash : $114.65
#   - Total Core NAV   : $158,961.07
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI     163.2926  $318.14   $51,949.92        32.68%
# XEL     692.9367   $78.85   $54,634.84        34.37%
# DLTR    477.2319  $109.51   $52,261.66        32.88%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $158,961.07
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# for linear_strategy
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.0% Cash
#   - Core Liquid Cash : $0.07
#   - Total Core NAV   : $91,593.24
#           Shares    Price Market Value Sleeve Weight
# Ticker
# ADI      97.6386  $318.14   $31,062.73        33.91%
# ALGN      0.0000  $171.43        $0.00         0.00%
# PANW      0.0000  $160.32        $0.00         0.00%
# CEG     104.9394  $278.82   $29,258.86        31.94%
# XEL       0.0000   $78.85        $0.00         0.00%
# DLTR    285.5592  $109.51   $31,271.58        34.14%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $91,593.24
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %%
# for advanced info strategy
g_state.display_current_state(today,market_prices)
# Out:
# ================================================================================
#  SYSTEM PORTFOLIO STATE SNAPSHOT: 2026-03-31
# ================================================================================
#
# [CORE SLEEVE] Allocation Ratio: 0.0% Cash
#   - Core Liquid Cash : $0.10
#   - Total Core NAV   : $129,977.29
#            Shares    Price Market Value Sleeve Weight
# Ticker
# ENPH    1092.8974   $37.81   $41,322.45        31.79%
# ALGN     258.5094  $171.43   $44,316.26        34.10%
# ADI      139.3678  $318.14   $44,338.48        34.11%
# INSM       0.0000  $163.52        $0.00         0.00%
#
# [TACTICAL SLEEVE] Allocation Ratio: 0.0% Cash
#   - Tactical Cash     : $0.00
#   - Total Tactical NAV: $0.00
#   (No active ad-hoc positions or trailing stops active in Tactical)
#
# --------------------------------------------------
#  CONSOLIDATED PORTFOLIO EQUITY NET VALUE: $129,977.29
#   - Core Allocation Weight     : 100.00%
#   - Tactical Allocation Weight : 0.00%
# --------------------------------------------------

# %% [markdown]
# ## daily level

# %%
from src import analysis

# %%
reload(analysis)
# Out:
# <module 'src.analysis' from '/Users/zhigangyu/Documents/Project Z/src/analysis.py'>

# %%
metric_keys=audit_ledger[0].telemetry.metrics.keys()
df_ledger=audit.analyze_audit_trail(audit_ledger,metric_keys)
df_ledger.shape
# Out:
# (1131, 9)

# %%
df_nav=g_state.export_nav_dataframe()[['Total_NAV']]
df_nav=df_nav.rename({'Total_NAV':'nav'},axis=1)

# %%
df_trade=analysis.parse_backtest_log('backtest.log')
df_trade['shares2']=np.where(df_trade['type']=='CORE_SELL',-1*df_trade['shares'],df_trade['shares'])

# %%
df_ledger['trade_date']=df_ledger['date']+ pd.Timedelta(days=1)

# %%
df_trade2=df_trade.merge(df_ledger[['trade_date','ticker','final_weight']],left_on=['date','ticker'],right_on=['trade_date','ticker'])

# %%
df_trade2
# Out:
#          date       type ticker   shares   price    fee  shares2 trade_date  \
# 0  2023-02-01   CORE_BUY   SNPS    90.63  367.05  33.30    90.63 2023-02-01
# 1  2023-02-01   CORE_BUY     ON   427.37   77.84  33.30   427.37 2023-02-01
# 2  2023-02-01   CORE_BUY   CDNS   176.12  188.89  33.30   176.12 2023-02-01
# 3  2023-03-01  CORE_SELL     ON   427.37   78.23  33.43  -427.37 2023-03-01
# 4  2023-03-01  CORE_SELL   CDNS     2.05  191.43   0.39    -2.05 2023-03-01
# ..        ...        ...    ...      ...     ...    ...      ...        ...
# 82 2025-10-01  CORE_SELL   INSM   373.10  147.28  54.95  -373.10 2025-10-01
# 83 2025-10-01  CORE_SELL   FAST  1116.95   46.96  52.45 -1116.95 2025-10-01
# 84 2025-10-01   CORE_BUY    XEL   685.36   78.52  53.87   685.36 2025-10-01
# 85 2025-10-01   CORE_BUY  GOOGL   220.16  244.42  53.87   220.16 2025-10-01
# 86 2025-10-01   CORE_BUY     ZS   176.71  304.53  53.87   176.71 2025-10-01
#
#     final_weight
# 0       0.333333
# 1       0.333333
# 2       0.333333
# 3       0.000000
# 4       0.333333
# ..           ...
# 82      0.000000
# 83      0.000000
# 84      0.333333
# 85      0.333333
# 86      0.333333
#
# [87 rows x 9 columns]

# %%
df_trade3=analysis.generate_balance_df(df_trade,daily_resolution=False)
df_trade3=analysis.unpivot_balance_df(df_trade3)
df_trade3.head()
# Out:
#          date ticker  shares
# 6  2023-02-01   CDNS  176.12
# 17 2023-02-01     ON  427.37
# 20 2023-02-01   SNPS   90.63
# 28 2023-03-01    ADI  190.84
# 31 2023-03-01   CDNS  174.07

# %%
df_trade3.head(10)
# Out:
#          date ticker  shares
# 6  2023-02-01   CDNS  176.12
# 17 2023-02-01     ON  427.37
# 20 2023-02-01   SNPS   90.63
# 28 2023-03-01    ADI  190.84
# 31 2023-03-01   CDNS  174.07
# 45 2023-03-01   SNPS   92.29
# 53 2023-04-03    ADI  193.52
# 56 2023-04-03   CDNS  170.84
# 65 2023-04-03   MDLZ  562.23
# 70 2023-04-03   SNPS   -0.01

# %%
reload(analysis)
# Out:
# <module 'src.analysis' from '/Users/zhigangyu/Documents/Project Z/src/analysis.py'>

# %%
df_prices=universe_data['price']
df_prices.index.name='date'

# %%
df_enhanced_ledger=analysis.build_enhanced_ledger_from_balances(df_trade3,df_prices)

# %%
# chech the nav by g_state record and our log history, mainly match
df1=df_enhanced_ledger.loc[df_enhanced_ledger['is_rebalance_day']]
df2=df1.groupby('date')[['current_value']].sum()
df_nav_match=df_nav.merge(df2, right_index=True,left_index=True)

# %%
df_nav_diff=df_nav_match.diff()
df_nav_diff.sort_values('nav').head()
# Out:
#                      nav  current_value
# Date
# 2025-01-02 -13090.253861  -13195.169994
# 2025-08-01 -12219.188676  -12313.880605
# 2026-03-02 -11803.938025  -11854.378509
# 2023-10-02  -9897.035718   -9933.959723
# 2025-03-03  -8561.390895   -8501.522291

# %%
idx=df_enhanced_ledger['cum_pnl'].idxmin()
print(df_enhanced_ledger.loc[idx])
lost_ticker=df_enhanced_ledger.loc[idx]['ticker']
df1=df_trade3.loc[df_trade3['ticker']==lost_ticker]
# Out:
# date                2026-02-05 00:00:00
# ticker                              AMD
# shares_holding                   248.09
# current_price                     192.5
# current_value                 47757.325
# yesterday_value            49665.137706
# return_change                 -0.038414
# pnl_dollar                 -1907.812706
# entry_price                  246.274345
# cum_pnl                    -13340.87726
# weight                         0.282397
# shares_change                       0.0
# is_rebalance_day                  False
# Name: 29760, dtype: object

# %%
first_date=df1.iloc[0]['date']+pd.Timedelta(days=-10)
last_date=df1.iloc[-1]['date']+pd.Timedelta(days=+10)

# %%
df2=df_enhanced_ledger.loc[(df_enhanced_ledger['date']>=first_date)&(df_enhanced_ledger['date']<=last_date)]

# %%
analysis.plot_ticker_attribution(df2,ticker_symbol=lost_ticker)

# %% [markdown]
# ## evaluation

# %%
from src import metrics

# %%
print('info_moment')
# Out:
# info_moment

# %% [markdown]
# # evaluateion on bootstrap results

# %%
from src import stat_test

# %%
def nav_all(nav_list,col='Total_NAV'):
    nav_all=pd.concat([nav[col] for nav in nav_list],axis=1)
    nav_all.columns=range(0,len(nav_list))
    return nav_all

# %%
risk_nav_all=nav_all(risk_navs)
risk_nav_metrics=metrics.calculate_metrics(risk_nav_all)

# %%
info_nav_all=nav_all(info_navs)
info_nav_metrics=metrics.calculate_metrics(info_nav_all)

# %%
risk_nav_metrics.columns
# Out:
# Index(['CAGR', 'Sharpe_Ratio', 'Sortino_Ratio', 'Max_Drawdown',
#        'Calmar_Ratio'],
#       dtype='str')

# %%
for column in risk_nav_metrics.columns:
    print(f'----{column}----')
    s1,s2=risk_nav_metrics[column],info_nav_metrics[column]
    # test_res=stat_test.test_paired_series_non_parametric(s1,s2)
    test_res=stat_test.automated_paired_test(s1,s2)
    if not test_res['significant_at_5pct']:
        print(f'different: {s1.mean()} ..vs.. {s2.mean()}')
    else:
        print(f'same: {s1.mean()} ..vs.. {s2.mean()}')
# Out:
# ----CAGR----
# same: 0.1799114853780623 ..vs.. 0.1924236832228953
# ----Sharpe_Ratio----
# same: 0.7392562372772251 ..vs.. 0.6993231332027183
# ----Sortino_Ratio----
# same: 1.876469755704342 ..vs.. 1.8034742959731789
# ----Max_Drawdown----
# same: 0.2614017594246385 ..vs.. 0.29531564838493124
# ----Calmar_Ratio----
# same: 0.9910205376658745 ..vs.. 0.9232063324783212

# %%
(info_nav_metrics[['CAGR']]-risk_nav_metrics[['CAGR']]).hist()
# Out:
# array([[<Axes: title={'center': 'CAGR'}>]], dtype=object)

# %% [markdown]
# # benchmark

# %%
engine_bench,prices_3d,volume_3d=run2.get_bootstrap_words(bench_universe_data,NUM_SIMULATIONS)

# %%
# Run the Macro Orchestrator validation pass
spy_navs=[]
qqq_navs=[]

for sim_id in tqdm(range(NUM_SIMULATIONS)):
    # Pack the 3D slices into clean 2D DataFrames with the ORIGINAL calendar dates index
    # world_data_dict = {
    #     'price': pd.DataFrame(prices_3d[sim_id, :, :], index=engine.dates_index, columns=engine.tickers),
    #     'volume': pd.DataFrame(volume_3d[sim_id, :, :], index=engine.dates_index, columns=engine.tickers)
    # }
    df_prices=pd.DataFrame(prices_3d[sim_id, :, :], index=engine_bench.dates_index, columns=engine_bench.tickers)
    spy_navs.append(df_prices[['SPY']])
    qqq_navs.append(df_prices[['QQQ']])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1313.10it/s]

# %%
assert len(spy_navs)==len(qqq_navs)==NUM_SIMULATIONS

# %%
spy_nav_all=nav_all(spy_navs,'SPY')
qqq_nav_all=nav_all(qqq_navs,'QQQ')

# %%
sqy_nav_metrics=metrics.calculate_metrics(spy_nav_all)
qqq_nav_metrics=metrics.calculate_metrics(qqq_nav_all)

# %%
for column in sqy_nav_metrics.columns:
    print(f'----{column}----')
    s1,s2=sqy_nav_metrics[column],qqq_nav_metrics[column]
    test_res=stat_test.test_paired_series_non_parametric(s1,s2)
    if not test_res['significant_at_5pct']:
        print(f'different: {s1.mean()} ..vs.. {s2.mean()}')
    else:
        print(f'same: {s1.mean()} ..vs.. {s2.mean()}')
# Out:
# ----CAGR----
# same: 0.09446482332172962 ..vs.. 0.10137824440424797
# ----Sharpe_Ratio----
# same: 0.7289833702412534 ..vs.. 0.6374972764882084
# ----Sortino_Ratio----
# same: 1.220004877043697 ..vs.. 1.0713361812131421
# ----Max_Drawdown----
# same: 0.25675941436112626 ..vs.. 0.34280337500446895
# ----Calmar_Ratio----
# same: 0.46998721726869935 ..vs.. 0.39476742605700077
